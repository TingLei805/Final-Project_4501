# %% [markdown]
# # NYC Apartment Search
#
# ### Group Members: Ting Lei, Diwen Shi
# ### UNI：【tl3266,ds4230】

# %% [markdown]
# ## Setup

# %% [markdown]
# _This is the part where we import all packages and functions we needed for the project._

# %%
import json
import pathlib
import os

import geoalchemy2 as gdb
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd
import requests
import shapely
import sqlalchemy as db
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# _Then we add all directories for our files_.
#
# _Here Ting Lei uses his password for postgres and set DB_PW as "postgres", which will become handy for other users to change._

# %%
DATA_DIR = "data"
ZIPCODE_DATA_FILE = DATA_DIR + "/nyc_zipcodes.shp"
ZILLOW_DATA_FILE = DATA_DIR + "/zillow_rent_data.csv"

NYC_DATA_APP_TOKEN = "Swia3cwdHIaSCmkBJBrjXKYaf"
BASE_NYC_DATA_URL = "https://data.cityofnewyork.us/"
NYC_DATA_311 = BASE_NYC_DATA_URL + f"resource/erm2-nwe9.csv?$$app_token={NYC_DATA_APP_TOKEN}&$select=created_date,incident_zip,latitude,longitude,complaint_type&$where=created_date BETWEEN '2022-10-01T00:00:00.000' AND '2023-09-30T23:59:59.999'&$limit=999999999"
NYC_DATA_TREES = BASE_NYC_DATA_URL + f"api/views/5rq2-4hqu/rows.csv?$$app_token={NYC_DATA_APP_TOKEN}"
NYC_DATA_311_FILE = DATA_DIR + "/311.csv"
NYC_DATA_TREE_FILE = DATA_DIR + "/tree.csv"


DB_NAME = "DataEda"
DB_USER = "postgres"
DB_PW = "postgres" # password
DB_URL = f"postgresql+psycopg2://{DB_USER}:{DB_PW}@localhost:5432/{DB_NAME}"
DB_SCHEMA_FILE = "schema.sql"
# directory where DB queries for Part 3 will be saved
QUERY_DIR = "queries"

os.makedirs(DATA_DIR, exist_ok=True)
os.makedirs(QUERY_DIR, exist_ok=True)

# %% [markdown]
# ## Part 1: Data Preprocessing

# %% [markdown]
# _We first download all the data from nyc websites and write the uncleaned data into files._

# %%
def download_311_tree_data():
    """
    This is a function to download data programmatically.

    If 311/tree file directory does not exist, this function will create a new file 
    under this directory using request method.

    Parameters:
    Does not have any parameters.

    Returns:
    No returns but simply generate two text files containing data.
    """
    print("downloading")
    if not os.path.exists(NYC_DATA_311_FILE):
        response311 = requests.get(NYC_DATA_311)
        if response311.status_code == 200:
            with open(NYC_DATA_311_FILE, "w", encoding="utf-8") as f:
                f.write(response311.text)
        else:
            raise Exception("Fail")

    if not os.path.exists(NYC_DATA_TREE_FILE):
        responsetree = requests.get(NYC_DATA_TREES)
        if responsetree.status_code == 200:
            with open(NYC_DATA_TREE_FILE, "w", encoding="utf-8") as f:
                f.write(responsetree.text)
        else:
            raise Exception("Fail")

# %% [markdown]
# _Then we define a function to load all data into pandas dataframe of which we can implement more programming usages._

# %%
def load_311_tree_data():
    """
    This is a function to read data into pandas dataframe.

    Use a default pandas index and specify incident_zip column as string type, also drop
    all rows that contain nan data and rename all imperative columns.

    Parameters:
    Does not have any parameters.

    Returns:
    311 and tree census dataframes.
    """
    data_311 = pd.read_csv(NYC_DATA_311_FILE, index_col=None, dtype={"incident_zip":str}) \
            .dropna() \
            .rename(columns={"created_date": "Time", "incident_zip": "ZipCode", "latitude": "Latitude", "longitude": "Longitude", "complaint_type":"ComplaintType"})

    data_tree = pd.read_csv(NYC_DATA_TREE_FILE, index_col=None, dtype={"zipcode": str}) \
        [["tree_id", "zipcode", "Latitude", "longitude", "spc_latin", "status", "health"]] \
        .rename(columns={"tree_id": "ID", "zipcode": "ZipCode", "longitude": "Longitude", "spc_latin": "Species", "status": "Status", "health": "Health"}) \
        .dropna()

    return data_311, data_tree

# %% [markdown]
# _This is a function to read all the existing data into dataframe, including zipcodes and zillow information._

# %%
def load_and_clean_zipcodes(zipcode_datafile):
    """a function of which paramter is the file directory of zipcode datafile and returns a geometry datafile"""
    nyc_shp = gpd.read_file(zipcode_datafile).to_crs(epsg=4326)
    return nyc_shp

def load_and_clean_zillow_data(zl_file):
    """a function of which paramter is the file directory of zillow data and returns a datafile"""
    zillow = pd.read_csv(zl_file, index_col=None)
    def expand_row(row):
        value = row[9:]
        df = pd.DataFrame({"Time": value.index, "Rent": value.values, "ZipCode": row["RegionName"]})
        return df
    zillow = pd.concat(zillow.apply(expand_row, axis=1).tolist(), ignore_index=True).dropna()
    return zillow

# %% [markdown]
# _Now we are ready to implement all the functions above._

# %%
def load_all_data():
    download_311_tree_data()
    geodf_zipcode_data = load_and_clean_zipcodes(ZIPCODE_DATA_FILE)
    geodf_311_data,geodf_tree_data = load_311_tree_data()
    df_zillow_data = load_and_clean_zillow_data(zl_file=ZILLOW_DATA_FILE)
    return (
        geodf_zipcode_data,
        geodf_311_data,
        geodf_tree_data,
        df_zillow_data
    )

# %% [markdown]
# _Downloading all the data we need in subsequent tasks_

# %%
geodf_zipcode_data, geodf_311_data, geodf_tree_data, df_zillow_data = load_all_data()
# Out:
# downloading

# %% [markdown]
# _Show basic info about each dataframe and show first 5 entries about each dataframe_

# %%
geodf_zipcode_data.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 263 entries, 0 to 262
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ZIPCODE     263 non-null    object
#  1   BLDGZIP     263 non-null    object
#  2   PO_NAME     263 non-null    object
#  3   POPULATION  263 non-null    float64
#  4   AREA        263 non-null    float64
#  5   STATE       263 non-null    object
#  6   COUNTY      263 non-null    object
#  7   ST_FIPS     263 non-null    object
#  8   CTY_FIPS    263 non-null    object
#  9   URL         263 non-null    object
#  10  SHAPE_AREA  263 non-null    float64
#  11  SHAPE_LEN   263 non-null    float64
#  12  geometry    263 non-null    geometry
# dtypes: float64(4), geometry(1), object(8)
# memory usage: 26.8+ KB

# %%
geodf_zipcode_data.head()
# Out:
#   ZIPCODE BLDGZIP   PO_NAME  POPULATION          AREA STATE  COUNTY ST_FIPS  \
# 0   11436       0   Jamaica     18681.0  2.269930e+07    NY  Queens      36
# 1   11213       0  Brooklyn     62426.0  2.963100e+07    NY   Kings      36
# 2   11212       0  Brooklyn     83866.0  4.197210e+07    NY   Kings      36
# 3   11225       0  Brooklyn     56527.0  2.369863e+07    NY   Kings      36
# 4   11218       0  Brooklyn     72280.0  3.686880e+07    NY   Kings      36
#
#   CTY_FIPS                   URL  SHAPE_AREA  SHAPE_LEN  \
# 0      081  http://www.usps.com/         0.0        0.0
# 1      047  http://www.usps.com/         0.0        0.0
# 2      047  http://www.usps.com/         0.0        0.0
# 3      047  http://www.usps.com/         0.0        0.0
# 4      047  http://www.usps.com/         0.0        0.0
#
#                                             geometry
# 0  POLYGON ((-73.80585 40.68291, -73.80569 40.682...
# 1  POLYGON ((-73.93740 40.67973, -73.93487 40.679...
# 2  POLYGON ((-73.90294 40.67084, -73.90223 40.668...
# 3  POLYGON ((-73.95797 40.67066, -73.95576 40.670...
# 4  POLYGON ((-73.97208 40.65060, -73.97192 40.650...

# %%
geodf_311_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3073388 entries, 0 to 3144579
# Data columns (total 5 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   Time           object
#  1   ZipCode        object
#  2   Latitude       float64
#  3   Longitude      float64
#  4   ComplaintType  object
# dtypes: float64(2), object(3)
# memory usage: 140.7+ MB

# %%
geodf_311_data.head()
# Out:
#                       Time ZipCode   Latitude  Longitude  \
# 0  2023-09-30T23:59:58.000   11226  40.655672 -73.959177
# 1  2023-09-30T23:59:38.000   11361  40.766756 -73.787518
# 2  2023-09-30T23:59:35.000   10002  40.719500 -73.984867
# 3  2023-09-30T23:59:34.000   11435  40.687499 -73.797290
# 4  2023-09-30T23:59:28.000   11226  40.652202 -73.957946
#
#              ComplaintType
# 0  Noise - Street/Sidewalk
# 1      Noise - Residential
# 2       Noise - Commercial
# 3      Noise - Residential
# 4      Noise - Residential

# %%
geodf_tree_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 652167 entries, 0 to 683787
# Data columns (total 7 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   ID         652167 non-null  int64
#  1   ZipCode    652167 non-null  object
#  2   Latitude   652167 non-null  float64
#  3   Longitude  652167 non-null  float64
#  4   Species    652167 non-null  object
#  5   Status     652167 non-null  object
#  6   Health     652167 non-null  object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 39.8+ MB

# %%
geodf_tree_data.head()
# Out:
#        ID ZipCode   Latitude  Longitude                             Species  \
# 0  180683   11375  40.723092 -73.844215                         Acer rubrum
# 1  200540   11357  40.794111 -73.818679                   Quercus palustris
# 2  204026   11211  40.717581 -73.936608  Gleditsia triacanthos var. inermis
# 3  204337   11211  40.713537 -73.934456  Gleditsia triacanthos var. inermis
# 4  189565   11215  40.666778 -73.975979                     Tilia americana
#
#   Status Health
# 0  Alive   Fair
# 1  Alive   Fair
# 2  Alive   Good
# 3  Alive   Good
# 4  Alive   Good

# %%
df_zillow_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 250167 entries, 0 to 705809
# Data columns (total 3 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   Time     250167 non-null  object
#  1   Rent     250167 non-null  object
#  2   ZipCode  250167 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 7.6+ MB

# %%
df_zillow_data.head()
# Out:
#          Time         Rent  ZipCode
# 0  2015-01-31  1606.206406    77494
# 1  2015-02-28  1612.779844    77494
# 2  2015-03-31  1622.201575    77494
# 3  2015-04-30  1630.392427    77494
# 4  2015-05-31    1632.4115    77494

# %% [markdown]
# ## Part 2: Storing Data

# %% [markdown]
# _In this part we will use spl schema to form a tabular and store all downloaded data inside._

# %%
import psycopg2
from psycopg2 import sql
from psycopg2.extensions import ISOLATION_LEVEL_AUTOCOMMIT

def setup_new_postgis_database(username, db_name):
    """Using SQL to create a new database and enable postgis extension"""
    try:
        connection = psycopg2.connect(user=username,password=DB_PW)
        connection.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT)

        with connection.cursor() as cursor:
            create_db_query = sql.SQL("CREATE DATABASE {}").format(sql.Identifier(db_name))
            cursor.execute(create_db_query)

        print(f"Database '{db_name}' created successfully!")

        connection.close()
        connection = psycopg2.connect(user=username, password=DB_PW,database=db_name)
        connection.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT)
        with connection.cursor() as cursor:
            create_extension_query = "CREATE EXTENSION IF NOT EXISTS postgis;"
            cursor.execute(create_extension_query)

        print("PostGIS extension enabled successfully!")

    except (Exception, psycopg2.Error) as error:
        print(f"Error while setting up database: {error}")

    finally:
        if connection:
            connection.close()

# %% [markdown]
# _Then we call the function above to create postgis database and enable postgis extension_

# %%
setup_new_postgis_database(DB_USER, DB_NAME)
# Out:
# Error while setting up database: 错误:  数据库 "DataEda" 已经存在

# %% [markdown]
# ### Creating Tables

# %% [markdown]
# _Here we created 4 tables respectively for zip codes, trees, 311 complaints and zillow rent information._
# _Each of which is formed in SQL schema and is written into a schema file._

# %%
engine = db.create_engine(DB_URL)

# %%
ZIPCODE_SCHEMA = """
DROP TABLE IF EXISTS "public"."ZipCode";
CREATE TABLE "public"."ZipCode" (
  "ZIPCODE" text COLLATE "pg_catalog"."default",
  "BLDGZIP" text COLLATE "pg_catalog"."default",
  "PO_NAME" text COLLATE "pg_catalog"."default",
  "POPULATION" float8,
  "AREA" float8,
  "STATE" text COLLATE "pg_catalog"."default",
  "COUNTY" text COLLATE "pg_catalog"."default",
  "ST_FIPS" text COLLATE "pg_catalog"."default",
  "CTY_FIPS" text COLLATE "pg_catalog"."default",
  "URL" text COLLATE "pg_catalog"."default",
  "SHAPE_AREA" float8,
  "SHAPE_LEN" float8,
  "geometry" "public"."geometry"
)
;

CREATE INDEX "idx_ZipCode_geometry" ON "public"."ZipCode" USING gist (
  "geometry" "public"."gist_geometry_ops_2d"
);
"""

NYC_311_SCHEMA = """
DROP TABLE IF EXISTS "public"."NYC_311";
CREATE TABLE "public"."NYC_311" (
  "ZipCode" varchar(10) COLLATE "pg_catalog"."default" NOT NULL,
  "Time" date NOT NULL,
  "Latitude" float8,
  "Longitude" float8,
  "ComplaintType" varchar(255) COLLATE "pg_catalog"."default"
)
;

"""

NYC_TREE_SCHEMA = """
DROP TABLE IF EXISTS "public"."NYC_Tree";
CREATE TABLE "public"."NYC_Tree" (
  "ID" int8 NOT NULL,
  "ZipCode" varchar(10) COLLATE "pg_catalog"."default",
  "Longitude" float8,
  "Latitude" float8,
  "Species" varchar(255) COLLATE "pg_catalog"."default",
  "Status" varchar(255) COLLATE "pg_catalog"."default",
  "Health" varchar(255) COLLATE "pg_catalog"."default"
)
;

ALTER TABLE "public"."NYC_Tree" ADD CONSTRAINT "Tree_pkey" PRIMARY KEY ("ID");
"""

ZILLOW_SCHEMA = """
DROP TABLE IF EXISTS "public"."Zillow";
CREATE TABLE "public"."Zillow" (
  "ZipCode" varchar(10) COLLATE "pg_catalog"."default" NOT NULL,
  "Time" date NOT NULL,
  "Rent" float4
)
;

ALTER TABLE "public"."Zillow" ADD CONSTRAINT "Rent_pkey" PRIMARY KEY ("ZipCode", "Time");

"""

# %%
# create that required schema.sql file
with open(DB_SCHEMA_FILE, "w") as f:
    f.write(ZIPCODE_SCHEMA)
    f.write(NYC_311_SCHEMA)
    f.write(NYC_TREE_SCHEMA)
    f.write(ZILLOW_SCHEMA)

# %% [markdown]
# _Then we execute the file and implement all SQL codes._

# %%
from sqlalchemy import text
with engine.connect() as connection:
    with open("schema.sql", 'r') as file:
        sql_script = text(file.read())
        connection.execute(sql_script)

# %% [markdown]
# ### Add Data to Database

# %%
tablename_to_dataframe = {
    "ZipCode": geodf_zipcode_data,
    "NYC_311": geodf_311_data,
    "NYC_Tree": geodf_tree_data,
    "Zillow": df_zillow_data,
}

# %%
geodf_zipcode_data.to_postgis('ZipCode', engine, if_exists='replace', index=False)

# %%
geodf_tree_data.to_sql('NYC_Tree', engine, if_exists='append', index=False)
# Out:
# 167

# %%
geodf_311_data.to_sql('NYC_311', engine, if_exists='append', index=False)
# Out:
# 388

# %%
df_zillow_data.to_sql('Zillow', engine, if_exists='append', index=False)
# Out:
# 167

# %% [markdown]
# ## Part 3: Understanding the Data

# %% [markdown]
# ### Query 1

# %% [markdown]
# _Here we write a simple helper function to easily write all queries into files and this function can be used in all queries._

# %%
# Helper function to write the queries to file
def write_query_to_file(query, outfile):
    with open(outfile, "w", encoding="utf-8") as f:
        f.write(query)

# %%
QUERY_1_FILENAME = QUERY_DIR + "/Q1.sql"

QUERY_1 = """
SELECT
    "ZipCode" AS zip_code,
    COUNT(*) AS number_of_311_complaints
FROM
    "NYC_311"
WHERE
    "Time" BETWEEN '2022-10-01 00:00:00' AND '2023-09-30 23:59:59'
GROUP BY
    "ZipCode"
ORDER BY
    number_of_311_complaints DESC;
"""
with engine.connect() as conn:
    result = conn.execute(db.text(QUERY_1))
    for row in result:
        print(row)
write_query_to_file(QUERY_1, QUERY_1_FILENAME)
# Out:
# ('11226', 49283)
# ('10467', 47364)
# ('10468', 44046)
# ('10452', 43858)
# ('11385', 43587)
# ('10457', 41499)
# ('10458', 41154)
# ('11207', 39922)
# ('10456', 39756)
# ('11201', 39230)
# ('10453', 38066)
# ('11208', 36496)
# ('10031', 33798)
# ('11221', 33078)
# ('10466', 32516)
# ('10032', 31974)
# ('10025', 30935)
# ('10462', 30720)
# ('11238', 30115)
# ('11230', 29444)
# ('11368', 29236)
# ('11220', 28847)
# ('10019', 28113)
# ('11216', 28068)
# ('11225', 28030)
# ('11235', 27685)
# ('11212', 27235)
# ('10460', 26956)
# ('10463', 26956)
# ('10023', 26805)
# ('11203', 26749)
# ('11214', 26632)
# ('11377', 26224)
# ('10027', 25785)
# ('11101', 25753)
# ('11213', 25734)
# ('10002', 25553)
# ('11211', 25466)
# ('11206', 25334)
# ('10472', 25334)
# ('11234', 25285)
# ('11222', 25262)
# ('11209', 25146)
# ('11215', 25129)
# ('11218', 24990)
# ('11233', 24876)
# ('11223', 24062)
# ('11373', 23929)
# ('10033', 23655)
# ('11237', 23320)
# ('11229', 22655)
# ('11236', 22376)
# ('10461', 22257)
# ('10034', 22248)
# ('10011', 22088)
# ('11204', 21658)
# ('10003', 21570)
# ('10026', 21261)
# ('10469', 21189)
# ('10009', 20998)
# ('11210', 20924)
# ('10029', 20809)
# ('10451', 20695)
# ('10036', 20683)
# ('11372', 20407)
# ('10459', 20282)
# ('11217', 20230)
# ('10040', 19833)
# ('10314', 19701)
# ('11231', 19556)
# ('11432', 19522)
# ('11419', 19478)
# ('11420', 19275)
# ('11378', 19032)
# ('11375', 18921)
# ('11219', 18827)
# ('11355', 18703)
# ('10455', 18392)
# ('11366', 18382)
# ('10035', 18268)
# ('10030', 18015)
# ('10016', 17075)
# ('11421', 17042)
# ('11205', 17008)
# ('10312', 16709)
# ('11434', 16614)
# ('11435', 16545)
# ('11414', 16136)
# ('10024', 16042)
# ('11691', 15842)
# ('10473', 15547)
# ('10306', 15539)
# ('11103', 15300)
# ('11106', 14936)
# ('11379', 14589)
# ('11224', 14417)
# ('11433', 14266)
# ('11105', 14247)
# ('10465', 14021)
# ('10028', 13965)
# ('11354', 13895)
# ('10301', 13619)
# ('10454', 13604)
# ('10014', 13360)
# ('10001', 13126)
# ('11249', 12941)
# ('11357', 12708)
# ('10304', 12680)
# ('11369', 12563)
# ('10013', 12337)
# ('11232', 12242)
# ('11102', 12221)
# ('11374', 12173)
# ('10039', 11957)
# ('11417', 11914)
# ('11365', 11860)
# ('10128', 11850)
# ('11228', 11834)
# ('11418', 11663)
# ('10012', 11510)
# ('11239', 11020)
# ('10305', 10748)
# ('11358', 10507)
# ('11413', 10490)
# ('11412', 10359)
# ('10309', 9866)
# ('11356', 9836)
# ('10022', 9686)
# ('11104', 9599)
# ('10021', 9587)
# ('10470', 8933)
# ('11361', 8928)
# ('11367', 8743)
# ('11416', 8467)
# ('11423', 8306)
# ('11694', 8253)
# ('10065', 8041)
# ('10037', 7939)
# ('10010', 7908)
# ('11422', 7816)
# ('10018', 7594)
# ('10471', 7551)
# ('11436', 7514)
# ('11370', 7236)
# ('11364', 6955)
# ('10474', 6782)
# ('10308', 6714)
# ('10310', 6680)
# ('10017', 6680)
# ('10038', 6675)
# ('10303', 6609)
# ('10302', 6410)
# ('11429', 6025)
# ('10075', 5703)
# ('11415', 5633)
# ('11692', 5596)
# ('11411', 5513)
# ('11428', 5359)
# ('11427', 4951)
# ('11693', 4200)
# ('11426', 4071)
# ('10007', 4024)
# ('11360', 3805)
# ('10307', 3735)
# ('10475', 3734)
# ('11362', 3191)
# ('11430', 3064)
# ('10464', 2535)
# ('10004', 2487)
# ('11004', 2360)
# ('10005', 2082)
# ('11363', 1865)
# ('11109', 1837)
# ('10006', 1578)
# ('10044', 1040)
# ('11001', 812)
# ('10282', 742)
# ('10000', 689)
# ('11040', 642)
# ('10069', 593)
# ('10280', 555)
# ('10020', 432)
# ('10169', 412)
# ('10121', 286)
# ('10107', 228)
# ('10278', 204)
# ('10105', 164)
# ('10153', 153)
# ('11359', 146)
# ('11697', 111)
# ('10172', 101)
# ('10151', 83)
# ('10103', 81)
# ('10281', 68)
# ('10168', 60)
# ('10118', 52)
# ('12345', 51)
# ('11005', 50)
# ('10120', 48)
# ('10106', 45)
# ('11251', 41)
# ('10162', 39)
# ('10119', 35)
# ('10271', 34)
# ('10041', 33)
# ('10112', 28)
# ('10165', 27)
# ('10045', 27)
# ('10170', 24)
# ('10110', 24)
# ('10171', 24)
# ('10048', 23)
# ('10178', 22)
# ('10154', 22)
# ('10158', 21)
# ('11371', 20)
# ('11241', 18)
# ('10123', 17)
# ('10174', 16)
# ('10179', 16)
# ('10279', 15)
# ('10177', 13)
# ('10111', 12)
# ('10115', 12)
# ('11695', 11)
# ('11242', 11)
# ('10176', 8)
# ('10166', 7)
# ('10152', 7)
# ('10173', 5)
# ('10122', 4)
# ('10155', 4)
# ('10167', 4)
# ('10803', 4)
# ('00083', 2)
# ('10055', 2)
# ('45040', 1)
# ('10175', 1)
# ('10550', 1)
# ('10080', 1)
# ('29601', 1)
# ('33496', 1)

# %% [markdown]
# ### Query 2

# %%
QUERY_2_FILENAME = QUERY_DIR + "/Q2.sql"

QUERY_2 = """
SELECT
    "ZipCode" AS zip_code,
    COUNT(*) AS top_tree_count
FROM
    "NYC_Tree"
GROUP BY
    "ZipCode"
ORDER BY
    top_tree_count DESC
LIMIT 10;
"""
with engine.connect() as conn:
    result = conn.execute(db.text(QUERY_2))
    for row in result:
        print(row)
write_query_to_file(QUERY_2, QUERY_2_FILENAME)
# Out:
# ('10312', 21356)
# ('10314', 16330)
# ('10306', 12616)
# ('10309', 12105)
# ('11234', 10838)
# ('11385', 10262)
# ('11357', 9016)
# ('11207', 8293)
# ('11208', 7896)
# ('11434', 7833)

# %% [markdown]
# ### Query 3

# %%
QUERY_3_FILENAME = QUERY_DIR + "/Q3.sql"

QUERY_3 = """
SELECT
    t.zip_code,
    ROUND(z."Rent"::numeric, 2) as rent,
    t.tree_count
FROM
    "Zillow" as z
RIGHT JOIN (
    SELECT
        "ZipCode" AS zip_code,
        COUNT(*) AS tree_count
    FROM
        "NYC_Tree"
    GROUP BY
        "ZipCode"
    ORDER BY
        tree_count DESC
    LIMIT 10
) AS t ON z."ZipCode" = t.zip_code
WHERE
    z."Time" = '2023-08-31';
"""
with engine.connect() as conn:
    result = conn.execute(db.text(QUERY_3))
    for row in result:
        print(row)
write_query_to_file(QUERY_3, QUERY_3_FILENAME)
# Out:
# ('10312', Decimal('1775.09'), 21356)
# ('10314', Decimal('2465.47'), 16330)
# ('10306', Decimal('2331.54'), 12616)
# ('10309', Decimal('1832.01'), 12105)
# ('11234', Decimal('2312.31'), 10838)
# ('11385', Decimal('3064.48'), 10262)
# ('11357', Decimal('2458.81'), 9016)
# ('11207', Decimal('3079.09'), 8293)
# ('11208', Decimal('2737.55'), 7896)
# ('11434', Decimal('2645.92'), 7833)

# %% [markdown]
# ### Query 4

# %%
QUERY_4_FILENAME = QUERY_DIR + "/Q4.sql"

QUERY_4 = """
WITH
  zillow_ranked_rent AS (
    SELECT
        "Rent",
        "ZipCode",
        ROW_NUMBER() OVER (ORDER BY "Rent") as rent_row_num_asc,
        ROW_NUMBER() OVER (ORDER BY "Rent" DESC) as rent_row_num_desc
    FROM
        "Zillow"
    WHERE
        "Time" = '2023-01-31'
  ),
  tree_count AS (
    SELECT
        "ZipCode",
        COUNT(*) AS tree_count
    FROM
        "NYC_Tree"
    GROUP BY
        "ZipCode"
  ),
  complaint_count AS (
    SELECT
        "ZipCode",
        COUNT(*) AS complaint_count
    FROM
        "NYC_311"
    GROUP BY
        "ZipCode"
  )

SELECT a."Rent", a."ZipCode", b.tree_count, c.complaint_count
FROM (
    SELECT "Rent", "ZipCode"
    FROM zillow_ranked_rent
    WHERE
        rent_row_num_asc <= 5
        OR rent_row_num_desc <= 5
) AS a
LEFT JOIN tree_count AS b ON a."ZipCode" = b."ZipCode"
LEFT JOIN complaint_count AS c ON a."ZipCode" = c."ZipCode";
"""
with engine.connect() as conn:
    result = conn.execute(db.text(QUERY_4))
    for row in result:
        print(row)
write_query_to_file(QUERY_4, QUERY_4_FILENAME)
# Out:
# (631.73834, '67501', None, None)
# (648.48755, '61832', None, None)
# (701.5791, '48503', None, None)
# (723.0447, '72114', None, None)
# (723.07056, '50702', None, None)
# (23662.299, '11954', None, None)
# (32893.574, '11937', None, None)
# (33056.44, '81611', None, None)
# (38626.57, '11968', None, None)
# (41561.336, '11963', None, None)

# %% [markdown]
# ### Query 5

# %%
QUERY_5_FILENAME = QUERY_DIR + "/Q5.sql"

QUERY_5 = """
SELECT
    z."ZIPCODE" as zip_code,
    COUNT(*) as tree_count
FROM
    "NYC_Tree" t
JOIN
    "ZipCode" z ON ST_Within(ST_SetSRID(ST_MakePoint(t."Longitude", t."Latitude"), 4326), z.geometry)
GROUP BY z."ZIPCODE"
ORDER BY tree_count DESC
LIMIT 10;
"""
with engine.connect() as conn:
    result = conn.execute(db.text(QUERY_5))
    for row in result:
        print(row)
write_query_to_file(QUERY_5, QUERY_5_FILENAME)
# Out:
# ('10312', 21356)
# ('10314', 16330)
# ('10306', 12616)
# ('10309', 12105)
# ('11234', 10838)
# ('11385', 10262)
# ('11357', 9016)
# ('11207', 8294)
# ('11208', 7897)
# ('11434', 7833)

# %% [markdown]
# ### Query 6

# %%
QUERY_6_FILENAME = QUERY_DIR + "/Q6.sql"

QUERY_6 = """
SELECT
    "ID",
    "ZipCode",
    "Species",
    "Status",
    "Health",
    CONCAT("Latitude", ', ', "Longitude") AS LatLng
FROM
    "NYC_Tree"
WHERE
    ST_DWithin(
        ST_MakePoint(-73.96253174434912, 40.80737875669467)::geography,
        ST_MakePoint("Longitude", "Latitude")::geography,
        0.5 * 1609.34
    );
"""
with engine.connect() as conn:
    result = conn.execute(db.text(QUERY_6))
    for row in result:
        print(row)
write_query_to_file(QUERY_6, QUERY_6_FILENAME)
# Out:
# (198514, '10025', 'Quercus palustris', 'Alive', 'Good', '40.80230109, -73.9620798')
# (209919, '10027', 'Platanus x acerifolia', 'Alive', 'Good', '40.80881155, -73.96331506')
# (209921, '10027', 'Platanus x acerifolia', 'Alive', 'Good', '40.80874458, -73.96340334')
# (203887, '10025', 'Quercus phellos', 'Alive', 'Good', '40.80572583, -73.96071917')
# (196440, '10115', 'Ulmus americana', 'Alive', 'Fair', '40.81114538, -73.96412322')
# (209913, '10027', 'Quercus palustris', 'Alive', 'Good', '40.80907709, -73.96312072')
# (178550, '10026', 'Acer platanoides', 'Alive', 'Good', '40.80690345, -73.95739877')
# (189403, '10027', 'Pyrus calleryana', 'Alive', 'Fair', '40.80754134, -73.95861206')
# (196606, '10024', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80732247, -73.96719944')
# (198512, '10025', 'Quercus palustris', 'Alive', 'Good', '40.80239611, -73.96230577')
# (196541, '10024', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80929314, -73.9654983')
# (203996, '10025', 'Pyrus calleryana', 'Alive', 'Good', '40.80528416, -73.96134249')
# (189414, '10027', 'Ginkgo biloba', 'Alive', 'Good', '40.80805619, -73.95983152')
# (196605, '10024', 'Ulmus americana', 'Alive', 'Good', '40.80738644, -73.96715782')
# (188558, '10025', 'Platanus x acerifolia', 'Alive', 'Good', '40.80361816, -73.96052882')
# (204127, '10025', 'Zelkova serrata', 'Alive', 'Fair', '40.80521641, -73.96208728')
# (188841, '10027', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.8088019, -73.95822529')
# (190326, '10026', 'Zelkova serrata', 'Alive', 'Good', '40.80385376, -73.95627225')
# (189406, '10027', 'Ginkgo biloba', 'Alive', 'Fair', '40.80767399, -73.95892624')
# (198510, '10025', 'Quercus palustris', 'Alive', 'Good', '40.80248808, -73.96252446')
# (209824, '10027', 'Quercus palustris', 'Alive', 'Good', '40.81089603, -73.9617956')
# (138615, '10027', 'Koelreuteria paniculata', 'Alive', 'Fair', '40.80900142, -73.95427116')
# (188843, '10027', 'Ginkgo biloba', 'Alive', 'Good', '40.80871253, -73.95801583')
# (203994, '10025', 'Pyrus calleryana', 'Alive', 'Fair', '40.80544227, -73.96171282')
# (209834, '10027', 'Quercus palustris', 'Alive', 'Fair', '40.81010258, -73.96237155')
# (193107, '10025', 'Quercus palustris', 'Alive', 'Good', '40.80283627, -73.96555738')
# (121484, '10025', 'Quercus shumardii', 'Alive', 'Poor', '40.80256195, -73.96312927')
# (198515, '10025', 'Quercus palustris', 'Alive', 'Good', '40.80223836, -73.96193064')
# (196613, '10025', 'Fraxinus pennsylvanica', 'Alive', 'Fair', '40.80656601, -73.96766169')
# (190331, '10026', 'Zelkova serrata', 'Alive', 'Good', '40.80408682, -73.9568291')
# (189405, '10027', 'Ginkgo biloba', 'Alive', 'Fair', '40.80763146, -73.95882551')
# (189413, '10027', 'Ginkgo biloba', 'Alive', 'Poor', '40.8080118, -73.95972638')
# (198511, '10025', 'Quercus palustris', 'Alive', 'Good', '40.80244289, -73.96241701')
# (209911, '10027', 'Quercus palustris', 'Alive', 'Good', '40.80919195, -73.96307592')
# (209912, '10027', 'Quercus palustris', 'Alive', 'Good', '40.80913778, -73.9630763')
# (190330, '10026', 'Zelkova serrata', 'Alive', 'Good', '40.80404418, -73.95672722')
# (188839, '10027', 'Ginkgo biloba', 'Alive', 'Fair', '40.8089231, -73.95850941')
# (188840, '10027', 'Ginkgo biloba', 'Alive', 'Fair', '40.8088668, -73.95837743')
# (196543, '10024', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80908661, -73.96564723')
# (196544, '10024', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80902644, -73.96569063')
# (189409, '10027', 'Ginkgo biloba', 'Alive', 'Good', '40.8078233, -73.95927989')
# (209832, '10027', 'Quercus palustris', 'Alive', 'Good', '40.81019253, -73.96234526')
# (188664, '10027', 'Quercus rubra', 'Alive', 'Good', '40.8063837, -73.95925026')
# (188561, '10025', 'Platanus x acerifolia', 'Alive', 'Good', '40.80392477, -73.96042285')
# (209918, '10027', 'Platanus x acerifolia', 'Alive', 'Fair', '40.80881155, -73.96331506')
# (209920, '10027', 'Platanus x acerifolia', 'Alive', 'Good', '40.80873191, -73.96337335')
# (203995, '10025', 'Pyrus calleryana', 'Alive', 'Poor', '40.80538715, -73.96158371')
# (198509, '10025', 'Quercus palustris', 'Alive', 'Good', '40.80259812, -73.96278614')
# (188559, '10025', 'Platanus x acerifolia', 'Alive', 'Good', '40.80372089, -73.96049331')
# (196616, '10024', 'Styphnolobium japonicum', 'Alive', 'Fair', '40.80634619, -73.96778354')
# (209833, '10027', 'Quercus palustris', 'Alive', 'Good', '40.81015301, -73.96233482')
# (209820, '10027', 'Quercus palustris', 'Alive', 'Fair', '40.81106551, -73.96171153')
# (76462, '10025', 'Syringa reticulata', 'Alive', 'Good', '40.80441608, -73.96750159')
# (193108, '10025', 'Quercus palustris', 'Alive', 'Fair', '40.80279369, -73.96545669')
# (209822, '10027', 'Quercus palustris', 'Alive', 'Good', '40.81096414, -73.96178527')
# (188560, '10025', 'Platanus x acerifolia', 'Alive', 'Good', '40.80382443, -73.96045753')
# (214747, '10027', 'Robinia pseudoacacia', 'Alive', 'Fair', '40.80852122, -73.96329637')
# (188547, '10025', 'Platanus x acerifolia', 'Alive', 'Good', '40.80234416, -73.96096912')
# (193112, '10025', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80260991, -73.96502208')
# (196546, '10025', 'Fraxinus pennsylvanica', 'Alive', 'Fair', '40.80838469, -73.96633015')
# (193113, '10025', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80254091, -73.96485891')
# (188546, '10025', 'Platanus x acerifolia', 'Alive', 'Good', '40.8021517, -73.96103563')
# (188545, '10025', 'Platanus x acerifolia', 'Alive', 'Good', '40.80205905, -73.96106765')
# (139761, '10026', 'Magnolia', 'Alive', 'Good', '40.80324293, -73.9565131')
# (187078, '10025', 'Zelkova serrata', 'Alive', 'Good', '40.80083357, -73.95997285')
# (188663, '10027', 'Quercus rubra', 'Alive', 'Good', '40.80630254, -73.95930941')
# (188665, '10027', 'Quercus rubra', 'Alive', 'Good', '40.80645957, -73.95919495')
# (209915, '10027', 'Quercus palustris', 'Alive', 'Good', '40.80902096, -73.9631618')
# (190327, '10026', 'Zelkova serrata', 'Alive', 'Good', '40.80392633, -73.95644563')
# (190328, '10026', 'Zelkova serrata', 'Alive', 'Good', '40.80396791, -73.95654498')
# (193104, '10025', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80297134, -73.96587679')
# (188666, '10027', 'Quercus rubra', 'Alive', 'Good', '40.80649871, -73.95916643')
# (190329, '10026', 'Zelkova serrata', 'Alive', 'Good', '40.80400975, -73.95664496')
# (193105, '10025', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.8029353, -73.96579157')
# (193109, '10025', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80275485, -73.96536485')
# (193111, '10025', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80265195, -73.9651215')
# (209916, '10027', 'Quercus palustris', 'Alive', 'Good', '40.80895471, -73.96324955')
# (187076, '10025', 'Zelkova serrata', 'Alive', 'Good', '40.80069671, -73.96007335')
# (209830, '10027', 'Quercus palustris', 'Alive', 'Good', '40.81031573, -73.96225554')
# (188667, '10027', 'Quercus rubra', 'Alive', 'Good', '40.80654817, -73.95913037')
# (193115, '10025', 'Quercus rubra', 'Alive', 'Good', '40.80240036, -73.96452656')
# (209993, '10025', 'Quercus palustris', 'Alive', 'Fair', '40.80660709, -73.96496366')
# (193163, '10025', 'Quercus rubra', 'Alive', 'Good', '40.80124342, -73.96177571')
# (188668, '10027', 'Quercus rubra', 'Alive', 'Good', '40.806613, -73.95908312')
# (193106, '10025', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80287511, -73.96564922')
# (209862, '10027', 'Quercus palustris', 'Alive', 'Poor', '40.80973254, -73.96268071')
# (209998, '10025', 'Quercus palustris', 'Alive', 'Good', '40.80635804, -73.96510628')
# (209780, '10027', 'Quercus palustris', 'Alive', 'Good', '40.81143414, -73.96137902')
# (209992, '10025', 'Quercus palustris', 'Alive', 'Fair', '40.80659444, -73.96493365')
# (193171, '10025', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80159331, -73.9626066')
# (187024, '10025', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80407594, -73.96318229')
# (187023, '10025', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80401577, -73.96322643')
# (193172, '10025', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80162683, -73.96268622')
# (193174, '10025', 'Tilia americana', 'Alive', 'Good', '40.80169348, -73.9628445')
# (188693, '10027', 'Quercus phellos', 'Alive', 'Fair', '40.80760658, -73.958356')
# (193167, '10025', 'Tilia americana', 'Alive', 'Poor', '40.80139215, -73.96212892')
# (209923, '10027', 'Quercus alba', 'Alive', 'Good', '40.8086352, -73.9634834')
# (188544, '10025', 'Platanus x acerifolia', 'Alive', 'Good', '40.80196427, -73.96110041')
# (193176, '10025', 'Pyrus calleryana', 'Alive', 'Good', '40.80183277, -73.96317528')
# (210161, '10025', 'Platanus x acerifolia', 'Alive', 'Good', '40.8052723, -73.96590138')
# (210163, '10025', 'Platanus x acerifolia', 'Alive', 'Good', '40.80522321, -73.96593682')
# (209776, '10027', 'Quercus palustris', 'Alive', 'Good', '40.81158252, -73.96127236')
# (210162, '10025', 'Platanus x acerifolia', 'Alive', 'Fair', '40.80523575, -73.9659669')
# (190325, '10026', 'Ulmus americana', 'Alive', 'Good', '40.80381403, -73.95617734')
# (190332, '10026', 'Ulmus americana', 'Alive', 'Good', '40.80416204, -73.95700881')
# (182932, '10026', 'Zelkova serrata', 'Alive', 'Good', '40.80337213, -73.95486513')
# (182934, '10026', 'Zelkova serrata', 'Alive', 'Good', '40.80352608, -73.95523023')
# (188669, '10027', 'Quercus rubra', 'Alive', 'Good', '40.80667663, -73.95903674')
# (196532, '10024', 'Ulmus parvifolia', 'Alive', 'Good', '40.81015708, -73.96486956')
# (182936, '10026', 'Ulmus parvifolia', 'Alive', 'Good', '40.80361172, -73.95543332')
# (209999, '10025', 'Quercus rubra', 'Alive', 'Good', '40.80633949, -73.96515907')
# (182931, '10026', 'Ulmus parvifolia', 'Alive', 'Good', '40.80330474, -73.95470532')
# (182933, '10026', 'Zelkova serrata', 'Alive', 'Good', '40.80341155, -73.95495862')
# (196533, '10024', 'Ulmus parvifolia', 'Alive', 'Good', '40.81004134, -73.9649539')
# (196531, '10024', 'Ulmus parvifolia', 'Alive', 'Fair', '40.81038808, -73.96470124')
# (207105, '10026', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80176592, -73.95740932')
# (218087, '10025', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80347733, -73.96741828')
# (217952, '10025', 'Ginkgo biloba', 'Alive', 'Good', '40.80328259, -73.96857522')
# (209856, '10027', 'Malus', 'Alive', 'Fair', '40.80982869, -73.96260947')
# (193175, '10025', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80176053, -73.96300373')
# (218086, '10025', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80342043, -73.96745978')
# (210003, '10025', 'Malus', 'Alive', 'Good', '40.80621349, -73.96525108')
# (217948, '10025', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.8030808, -73.96809468')
# (218085, '10025', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.8033633, -73.96750146')
# (196537, '10024', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80967202, -73.96522509')
# (182937, '10026', 'Ulmus parvifolia', 'Alive', 'Good', '40.80366499, -73.95555965')
# (217954, '10025', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80342344, -73.96891064')
# (210002, '10025', 'Malus', 'Alive', 'Good', '40.80620083, -73.96522107')
# (183144, '10026', 'Gleditsia triacanthos var. inermis', 'Alive', 'Fair', '40.80400072, -73.95415551')
# (183146, '10026', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80410707, -73.95440708')
# (193170, '10025', 'Pyrus calleryana', 'Alive', 'Good', '40.80155965, -73.96252667')
# (209774, '10027', 'Malus', 'Alive', 'Good', '40.81161408, -73.96124967')
# (209777, '10027', 'Quercus palustris', 'Alive', 'Good', '40.81150908, -73.96128605')
# (217949, '10025', 'Ginkgo biloba', 'Alive', 'Good', '40.80311093, -73.96816644')
# (217951, '10025', 'Ginkgo biloba', 'Alive', 'Good', '40.80322975, -73.96844939')
# (209859, '10027', 'Malus', 'Alive', 'Poor', '40.80977045, -73.96261324')
# (196540, '10024', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80937306, -73.96544067')
# (196536, '10024', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80973653, -73.96517857')
# (196538, '10024', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80950208, -73.96534763')
# (217947, '10025', 'Ginkgo biloba', 'Alive', 'Fair', '40.80303115, -73.96797644')
# (209858, '10027', 'Malus', 'Alive', 'Poor', '40.80980549, -73.96262666')
# (207104, '10026', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80170019, -73.95745741')
# (193169, '10025', 'Pyrus calleryana', 'Alive', 'Good', '40.8015059, -73.96239903')
# (209867, '10027', 'Quercus palustris', 'Alive', 'Good', '40.80955855, -73.96277025')
# (209779, '10027', 'Quercus palustris', 'Alive', 'Good', '40.81145199, -73.96132709')
# (210000, '10025', 'Quercus palustris', 'Alive', 'Good', '40.80629396, -73.96515307')
# (193168, '10025', 'Pyrus calleryana', 'Alive', 'Good', '40.80145189, -73.96227077')
# (210166, '10025', 'Platanus x acerifolia', 'Alive', 'Poor', '40.80509256, -73.96607025')
# (209860, '10027', 'Malus', 'Alive', 'Poor', '40.80978325, -73.96264314')
# (210169, '10025', 'Platanus x acerifolia', 'Alive', 'Good', '40.80499146, -73.96610409')
# (209825, '10027', 'Quercus palustris', 'Alive', 'Fair', '40.81083189, -73.96184226')
# (209864, '10027', 'Quercus palustris', 'Alive', 'Good', '40.80966366, -73.96273175')
# (209827, '10027', 'Quercus palustris', 'Alive', 'Good', '40.81074037, -73.96190884')
# (209995, '10025', 'Quercus palustris', 'Alive', 'Good', '40.80652645, -73.96502255')
# (209861, '10027', 'Quercus palustris', 'Alive', 'Good', '40.80973769, -73.96263752')
# (207247, '10026', 'Pyrus calleryana', 'Alive', 'Fair', '40.8037238, -73.95792265')
# (214749, '10027', 'Platanus x acerifolia', 'Alive', 'Fair', '40.80882617, -73.96307414')
# (210167, '10025', 'Platanus x acerifolia', 'Alive', 'Fair', '40.80505114, -73.96606101')
# (182935, '10026', 'Zelkova serrata', 'Alive', 'Good', '40.80358069, -73.95535973')
# (209863, '10027', 'Quercus palustris', 'Alive', 'Poor', '40.80967024, -73.96268749')
# (190324, '10026', 'Ulmus americana', 'Alive', 'Good', '40.80377298, -73.95607926')
# (193164, '10025', 'Ulmus americana', 'Alive', 'Poor', '40.80130422, -73.96192009')
# (210165, '10025', 'Platanus x acerifolia', 'Alive', 'Fair', '40.805152, -73.96602735')
# (209866, '10027', 'Quercus palustris', 'Alive', 'Fair', '40.80960482, -73.96277535')
# (209826, '10027', 'Quercus palustris', 'Alive', 'Fair', '40.81081616, -73.96189291')
# (209997, '10025', 'Quercus rubra', 'Alive', 'Good', '40.80640021, -73.96511473')
# (209869, '10027', 'Quercus palustris', 'Alive', 'Good', '40.80949803, -73.96281509')
# (210168, '10025', 'Platanus x acerifolia', 'Alive', 'Poor', '40.80503697, -73.96611038')
# (209775, '10027', 'Malus', 'Alive', 'Poor', '40.81160396, -73.96125695')
# (196539, '10024', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80943997, -73.96539242')
# (188599, '10025', 'Ulmus americana', 'Alive', 'Good', '40.80423795, -73.96031734')
# (210001, '10025', 'Malus', 'Alive', 'Good', '40.80624589, -73.96522742')
# (214738, '10027', 'Ginkgo biloba', 'Alive', 'Fair', '40.80681876, -73.96453698')
# (209857, '10027', 'Malus', 'Alive', 'Poor', '40.80982869, -73.96260947')
# (217953, '10025', 'Ginkgo biloba', 'Alive', 'Good', '40.80336928, -73.96878166')
# (214739, '10027', 'Ginkgo biloba', 'Alive', 'Fair', '40.80692442, -73.96445999')
# (214741, '10027', 'Ginkgo biloba', 'Alive', 'Fair', '40.8070805, -73.96434625')
# (183149, '10026', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80430936, -73.9548856')
# (122014, '10025', 'Metasequoia glyptostroboides', 'Alive', 'Fair', '40.80030239, -73.96318663')
# (207094, '10026', 'Ginkgo biloba', 'Alive', 'Good', '40.80086888, -73.95839117')
# (209922, '10027', 'Platanus x acerifolia', 'Alive', 'Fair', '40.808705, -73.96343231')
# (188598, '10025', 'Ulmus americana', 'Alive', 'Good', '40.80408268, -73.9603697')
# (188602, '10025', 'Ulmus americana', 'Alive', 'Good', '40.80455355, -73.96021091')
# (218082, '10025', 'Ulmus americana', 'Alive', 'Fair', '40.80310691, -73.96768848')
# (183147, '10026', 'Ulmus americana', 'Alive', 'Good', '40.80417406, -73.95456553')
# (207148, '10026', 'Gleditsia triacanthos var. inermis', 'Alive', 'Fair', '40.80208764, -73.95717327')
# (209778, '10027', 'Quercus rubra', 'Alive', 'Good', '40.81147849, -73.96130804')
# (210123, '10025', 'Malus', 'Alive', 'Good', '40.80592569, -73.96542253')
# (210125, '10025', 'Malus', 'Alive', 'Good', '40.80591818, -73.96546726')
# (207246, '10026', 'Platanus x acerifolia', 'Alive', 'Fair', '40.80378049, -73.95806787')
# (188601, '10025', 'Ulmus americana', 'Alive', 'Good', '40.80439535, -73.96026426')
# (214742, '10027', 'Ginkgo biloba', 'Alive', 'Poor', '40.80740466, -73.96411003')
# (188600, '10025', 'Ulmus americana', 'Alive', 'Good', '40.80431772, -73.96029044')
# (183148, '10026', 'Ulmus americana', 'Alive', 'Good', '40.80423757, -73.95471578')
# (218083, '10025', 'Ulmus americana', 'Alive', 'Good', '40.80317437, -73.96763927')
# (196619, '10024', 'Fraxinus pennsylvanica', 'Alive', 'Good', '40.80609322, -73.96791598')
# (190357, '10026', 'Fraxinus pennsylvanica', 'Alive', 'Fair', '40.80455495, -73.95793759')
# (188671, '10027', 'Pyrus calleryana', 'Alive', 'Good', '40.80710234, -73.95872645')
# (214743, '10027', 'Pyrus calleryana', 'Alive', 'Fair', '40.80764478, -73.96393505')
# (188672, '10027', 'Pyrus calleryana', 'Alive', 'Good', '40.80719838, -73.95865644')
# (214744, '10027', 'Pyrus calleryana', 'Alive', 'Fair', '40.80771922, -73.96388081')
# (217812, '10025', 'Styphnolobium japonicum', 'Alive', 'Good', '40.80276141, -73.96902175')
# (214740, '10027', 'Ginkgo biloba', 'Alive', 'Poor', '40.80698685, -73.96441449')
# (196586, '10025', 'Liquidambar styraciflua', 'Alive', 'Poor', '40.80721344, -73.96706368')
# (203841, '10025', 'Celtis occidentalis', 'Alive', 'Fair', '40.80481916, -73.96219406')
# (225204, '10026', 'Styphnolobium japonicum', 'Alive', 'Good', '40.80205878, -73.95760107')
# (135268, '10026', 'Acer nigrum', 'Alive', 'Good', '40.81047273, -73.95607858')
# (217814, '10025', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80264963, -73.96875721')
# (203844, '10025', 'Celtis occidentalis', 'Alive', 'Poor', '40.80433701, -73.96105405')
# (207301, '10026', 'Zelkova serrata', 'Alive', 'Good', '40.80383519, -73.9575928')
# (138837, '10027', 'Betula papyrifera', 'Alive', 'Fair', '40.81051518, -73.95424817')
# (138838, '10027', 'Betula papyrifera', 'Alive', 'Good', '40.81054278, -73.95431476')
# (203842, '10025', 'Celtis occidentalis', 'Alive', 'Poor', '40.80478525, -73.96211389')
# (203846, '10025', 'Celtis occidentalis', 'Alive', 'Fair', '40.80418803, -73.96070183')
# (188842, '10027', 'Styphnolobium japonicum', 'Alive', 'Good', '40.80875782, -73.95812198')
# (189404, '10027', 'Acer rubrum', 'Alive', 'Fair', '40.80758534, -73.95871626')
# (209917, '10027', 'Quercus palustris', 'Alive', 'Good', '40.8088921, -73.96329537')
# (210157, '10025', 'Magnolia', 'Alive', 'Good', '40.80533754, -73.96589343')
# (207304, '10026', 'Quercus imbricaria', 'Alive', 'Fair', '40.8040129, -73.95577149')
# (182991, '10026', 'Styphnolobium japonicum', 'Alive', 'Fair', '40.80417799, -73.95505518')
# (207284, '10026', 'Platanus x acerifolia', 'Alive', 'Fair', '40.80422212, -73.95750449')
# (214753, '10027', 'Quercus phellos', 'Alive', 'Fair', '40.80926079, -73.96275741')
# (217950, '10025', 'Tilia cordata', 'Alive', 'Good', '40.8031578, -73.96827804')
# (214755, '10027', 'Quercus phellos', 'Alive', 'Good', '40.80951771, -73.96257017')
# (207283, '10026', 'Platanus x acerifolia', 'Alive', 'Fair', '40.80411777, -73.95757935')
# (214752, '10027', 'Quercus phellos', 'Alive', 'Fair', '40.80914313, -73.96284315')
# (214754, '10027', 'Quercus phellos', 'Alive', 'Fair', '40.80936404, -73.96268216')
# (214751, '10027', 'Quercus phellos', 'Alive', 'Fair', '40.80906389, -73.9629009')
# (196542, '10024', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80914583, -73.96560453')
# (209781, '10027', 'Prunus cerasifera', 'Alive', 'Poor', '40.81132191, -73.96142059')
# (207095, '10026', 'Ginkgo biloba', 'Alive', 'Fair', '40.80089816, -73.95830106')
# (209771, '10027', 'Prunus', 'Alive', 'Good', '40.81164467, -73.96122768')
# (207298, '10026', 'Platanus x acerifolia', 'Alive', 'Fair', '40.80415897, -73.9573557')
# (209783, '10027', 'Prunus cerasifera', 'Alive', 'Good', '40.81131562, -73.96146422')
# (209784, '10027', 'Prunus cerasifera', 'Alive', 'Good', '40.81130312, -73.9614341')
# (209782, '10027', 'Prunus cerasifera', 'Alive', 'Good', '40.8113267, -73.96145625')
# (182995, '10026', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80397435, -73.9545702')
# (217815, '10025', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80260881, -73.96866061')
# (217811, '10025', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80290533, -73.96936237')
# (207299, '10026', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80407623, -73.95741629')
# (207149, '10026', 'Gleditsia triacanthos var. inermis', 'Alive', 'Fair', '40.80217513, -73.95710903')
# (207151, '10026', 'Gleditsia triacanthos var. inermis', 'Alive', 'Fair', '40.80241145, -73.95693548')
# (182993, '10026', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80406767, -73.95479246')
# (210124, '10025', 'Malus', 'Alive', 'Good', '40.80593834, -73.96545254')
# (207205, '10026', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.8025625, -73.95710786')
# (196442, '10115', 'Ulmus americana', 'Alive', 'Fair', '40.81094364, -73.96427309')
# (207207, '10026', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.8026616, -73.95734324')
# (225206, '10026', 'Tilia americana', 'Alive', 'Fair', '40.80218015, -73.95788794')
# (207204, '10026', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80251515, -73.95699539')
# (207297, '10026', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80447258, -73.95712953')
# (217817, '10025', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.8024825, -73.96836166')
# (182994, '10026', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80402878, -73.95469982')
# (182996, '10026', 'Quercus palustris', 'Alive', 'Good', '40.80394262, -73.95449464')
# (225209, '10026', 'Tilia americana', 'Alive', 'Good', '40.8023688, -73.95833386')
# (182992, '10026', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80410776, -73.95488793')
# (207206, '10026', 'Gleditsia triacanthos var. inermis', 'Alive', 'Fair', '40.80260241, -73.95720265')
# (225208, '10026', 'Tilia americana', 'Alive', 'Good', '40.80228736, -73.95814135')
# (207255, '10026', 'Platanus x acerifolia', 'Alive', 'Poor', '40.80357125, -73.95797804')
# (207230, '10026', 'Platanus x acerifolia', 'Alive', 'Good', '40.80361378, -73.95814093')
# (207296, '10026', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80458728, -73.95704572')
# (203848, '10025', 'Celtis occidentalis', 'Alive', 'Fair', '40.80410874, -73.96051435')
# (188845, '10027', 'Styphnolobium japonicum', 'Alive', 'Good', '40.8086393, -73.95784417')
# (225205, '10026', 'Styphnolobium japonicum', 'Alive', 'Good', '40.80209243, -73.9576806')
# (222714, '10025', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80071455, -73.96221391')
# (139764, '10026', 'Magnolia', 'Alive', 'Good', '40.80340872, -73.95690633')
# (139766, '10026', 'Magnolia', 'Alive', 'Fair', '40.80355134, -73.9572446')
# (210173, '10025', 'Magnolia', 'Alive', 'Good', '40.80494624, -73.96617586')
# (188670, '10027', 'Pyrus calleryana', 'Alive', 'Good', '40.80701158, -73.9587926')
# (188998, '10027', 'Robinia pseudoacacia', 'Alive', 'Fair', '40.8085443, -73.95903643')
# (207263, '10026', 'Pyrus calleryana', 'Alive', 'Good', '40.80383829, -73.95792224')
# (207211, '10026', 'Tilia tomentosa', 'Alive', 'Fair', '40.80299708, -73.95814007')
# (207262, '10026', 'Pyrus calleryana', 'Alive', 'Good', '40.80387244, -73.95800388')
# (193177, '10025', 'Pyrus calleryana', 'Alive', 'Good', '40.80184554, -73.96320561')
# (209964, '10025', 'Quercus palustris', 'Alive', 'Fair', '40.80698045, -73.9646534')
# (207209, '10026', 'Tilia tomentosa', 'Alive', 'Good', '40.80290995, -73.95793312')
# (210134, '10025', 'Malus', 'Alive', 'Good', '40.80558361, -73.96571156')
# (222717, '10025', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80132547, -73.96366257')
# (209963, '10025', 'Quercus palustris', 'Alive', 'Good', '40.80701751, -73.96466592')
# (188837, '10027', 'Gymnocladus dioicus', 'Alive', 'Fair', '40.80901462, -73.95872391')
# (217813, '10025', 'Styphnolobium japonicum', 'Alive', 'Good', '40.80272793, -73.96894251')
# (207147, '10026', 'Styphnolobium japonicum', 'Alive', 'Good', '40.80199297, -73.9572428')
# (209962, '10025', 'Quercus palustris', 'Alive', 'Good', '40.80703903, -73.96461143')
# (207294, '10026', 'Pyrus calleryana', 'Alive', 'Good', '40.80450149, -73.95729851')
# (190355, '10026', 'Celtis occidentalis', 'Alive', 'Good', '40.80438033, -73.95752313')
# (193173, '10025', 'Prunus', 'Alive', 'Good', '40.80165464, -73.96275225')
# (190356, '10026', 'Fraxinus pennsylvanica', 'Alive', 'Fair', '40.80449479, -73.9577948')
# (196580, '10024', 'Fraxinus pennsylvanica', 'Alive', 'Good', '40.80772711, -73.96692235')
# (222752, '10025', 'Zelkova serrata', 'Alive', 'Good', '40.801845, -73.96454702')
# (196577, '10024', 'Fraxinus americana', 'Alive', 'Poor', '40.80805502, -73.9666772')
# (159206, '10025', 'Eucommia ulmoides', 'Alive', 'Fair', '40.80111719, -73.9634945')
# (209926, '10027', 'Platanus x acerifolia', 'Alive', 'Fair', '40.80852897, -73.96352187')
# (209927, '10027', 'Platanus x acerifolia', 'Alive', 'Fair', '40.8085071, -73.96357715')
# (209929, '10027', 'Platanus x acerifolia', 'Alive', 'Fair', '40.80840951, -73.9636093')
# (209928, '10027', 'Platanus x acerifolia', 'Alive', 'Fair', '40.80845529, -73.96361507')
# (209924, '10027', 'Platanus x acerifolia', 'Alive', 'Poor', '40.80859518, -73.96347342')
# (209925, '10027', 'Platanus x acerifolia', 'Alive', 'Fair', '40.80857523, -73.96352729')
# (210212, '10025', 'Platanus x acerifolia', 'Alive', 'Fair', '40.80466251, -73.96635636')
# (210216, '10025', 'Platanus x acerifolia', 'Alive', 'Fair', '40.80449908, -73.96651028')
# (210126, '10025', 'Malus', 'Alive', 'Good', '40.80588705, -73.96545075')
# (210211, '10025', 'Platanus x acerifolia', 'Alive', 'Fair', '40.80470312, -73.9663667')
# (210213, '10025', 'Platanus x acerifolia', 'Alive', 'Fair', '40.80457513, -73.96641785')
# (225089, '10026', 'Ginkgo biloba', 'Alive', 'Good', '40.80104493, -73.95907904')
# (225084, '10026', 'Ginkgo biloba', 'Alive', 'Good', '40.8008287, -73.95859419')
# (225092, '10026', 'Ginkgo biloba', 'Alive', 'Good', '40.80114253, -73.95931261')
# (209837, '10027', 'Malus', 'Alive', 'Poor', '40.81006981, -73.96243463')
# (210133, '10025', 'Malus', 'Alive', 'Good', '40.80560233, -73.96569789')
# (225088, '10026', 'Ginkgo biloba', 'Alive', 'Fair', '40.80097854, -73.95892016')
# (225091, '10026', 'Ginkgo biloba', 'Alive', 'Good', '40.80111886, -73.95925596')
# (190358, '10026', 'Fraxinus pennsylvanica', 'Alive', 'Fair', '40.80458822, -73.95801656')
# (183145, '10026', 'Gleditsia triacanthos var. inermis', 'Alive', 'Fair', '40.80404449, -73.95425904')
# (225085, '10026', 'Ginkgo biloba', 'Alive', 'Good', '40.80085549, -73.95864732')
# (225087, '10026', 'Ginkgo biloba', 'Alive', 'Fair', '40.80094494, -73.95883977')
# (203843, '10025', 'Acer', 'Alive', 'Poor', '40.80460104, -73.96167834')
# (203845, '10025', 'Celtis occidentalis', 'Alive', 'Fair', '40.80423208, -73.96080598')
# (214750, '10027', 'Quercus acutissima', 'Alive', 'Fair', '40.80899185, -73.96295339')
# (225025, '10025', 'Styphnolobium japonicum', 'Alive', 'Good', '40.80200429, -73.96469673')
# (210127, '10025', 'Quercus palustris', 'Alive', 'Good', '40.8058685, -73.96550354')
# (210129, '10025', 'Quercus palustris', 'Alive', 'Good', '40.80580826, -73.96554752')
# (225024, '10025', 'Styphnolobium japonicum', 'Alive', 'Fair', '40.80191902, -73.96475879')
# (210218, '10025', 'Prunus', 'Alive', 'Good', '40.80441587, -73.96652993')
# (222755, '10025', 'Styphnolobium japonicum', 'Alive', 'Good', '40.80204029, -73.96440274')
# (193114, '10025', 'Celtis occidentalis', 'Alive', 'Good', '40.80249032, -73.96473929')
# (210130, '10025', 'Quercus palustris', 'Alive', 'Good', '40.80571825, -73.96561324')
# (225027, '10025', 'Styphnolobium japonicum', 'Alive', 'Good', '40.80219787, -73.96455582')
# (210215, '10025', 'Prunus cerasifera', 'Alive', 'Fair', '40.80452546, -73.96649172')
# (210219, '10025', 'Prunus', 'Alive', 'Good', '40.80441388, -73.96657024')
# (121485, '10025', 'Quercus shumardii', 'Alive', 'Good', '40.80264431, -73.9633269')
# (214748, '10027', 'Robinia pseudoacacia', 'Alive', 'Poor', '40.80872052, -73.96315113')
# (203847, '10025', 'Celtis occidentalis', 'Alive', 'Good', '40.80414665, -73.96060399')
# (232012, '10026', 'Quercus palustris', 'Alive', 'Good', '40.80485098, -73.95665182')
# (210217, '10025', 'Platanus x acerifolia', 'Alive', 'Fair', '40.80445793, -73.96653924')
# (210214, '10025', 'Platanus x acerifolia', 'Alive', 'Fair', '40.80455814, -73.96646872')
# (209930, '10027', 'Platanus x acerifolia', 'Alive', 'Fair', '40.80834523, -73.96365635')
# (231989, '10026', 'Platanus x acerifolia', 'Alive', 'Good', '40.80496262, -73.95643113')
# (209839, '10027', 'Malus', 'Alive', 'Fair', '40.81004916, -73.96244968')
# (225090, '10026', 'Ginkgo biloba', 'Alive', 'Poor', '40.80109598, -73.95920121')
# (210136, '10025', 'Malus', 'Alive', 'Good', '40.80556225, -73.96572716')
# (76463, '10025', 'Syringa reticulata', 'Alive', 'Good', '40.80437853, -73.96741334')
# (209836, '10027', 'Malus', 'Alive', 'Poor', '40.81008038, -73.96242694')
# (210135, '10025', 'Malus', 'Alive', 'Good', '40.8055496, -73.96569715')
# (222715, '10025', 'Fraxinus pennsylvanica', 'Alive', 'Good', '40.8007605, -73.96232287')
# (193178, '10025', 'Pyrus calleryana', 'Alive', 'Good', '40.80188838, -73.96330734')
# (198524, '10026', 'Ulmus americana', 'Alive', 'Good', '40.80174954, -73.96067732')
# (198531, '10026', 'Quercus phellos', 'Alive', 'Good', '40.80156214, -73.9603049')
# (198536, '10026', 'Ulmus americana', 'Alive', 'Fair', '40.8013474, -73.95972678')
# (222753, '10025', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80189765, -73.96450812')
# (193179, '10025', 'Pyrus calleryana', 'Alive', 'Good', '40.80192323, -73.96339011')
# (209838, '10027', 'Malus', 'Alive', 'Good', '40.81003654, -73.96241965')
# (198535, '10026', 'Ulmus americana', 'Alive', 'Good', '40.80138131, -73.95980694')
# (198522, '10026', 'Quercus phellos', 'Alive', 'Fair', '40.80176667, -73.96078837')
# (198532, '10026', 'Ulmus americana', 'Alive', 'Good', '40.80153285, -73.96016513')
# (198530, '10026', 'Quercus phellos', 'Alive', 'Good', '40.80159418, -73.96038064')
# (231987, '10026', 'Quercus palustris', 'Alive', 'Good', '40.80484411, -73.9561496')
# (210132, '10025', 'Quercus palustris', 'Alive', 'Good', '40.80561536, -73.96564913')
# (139762, '10026', 'Magnolia', 'Alive', 'Good', '40.80328595, -73.95661512')
# (209965, '10025', 'Quercus palustris', 'Alive', 'Good', '40.80691995, -73.96469677')
# (207305, '10026', 'Quercus imbricaria', 'Alive', 'Good', '40.80406216, -73.9557357')
# (210131, '10025', 'Quercus palustris', 'Alive', 'Good', '40.80565993, -73.96565583')
# (231986, '10026', 'Quercus palustris', 'Alive', 'Good', '40.80476377, -73.95595876')
# (231984, '10026', 'Quercus palustris', 'Alive', 'Good', '40.8046148, -73.95560488')
# (198529, '10026', 'Ulmus americana', 'Alive', 'Good', '40.80164326, -73.96042612')
# (198533, '10026', 'Ulmus americana', 'Alive', 'Good', '40.80148318, -73.96004773')
# (198534, '10026', 'Ulmus americana', 'Alive', 'Good', '40.80144059, -73.95994706')
# (209966, '10025', 'Quercus palustris', 'Alive', 'Good', '40.80690542, -73.96474625')
# (76464, '10025', 'Syringa reticulata', 'Alive', 'Good', '40.80435788, -73.9673648')
# (198526, '10026', 'Ulmus americana', 'Alive', 'Good', '40.8016968, -73.96055266')
# (232016, '10026', 'Quercus phellos', 'Alive', 'Fair', '40.80457947, -73.95600737')
# (198523, '10026', 'Quercus phellos', 'Alive', 'Poor', '40.80173103, -73.96070411')
# (198525, '10026', 'Quercus phellos', 'Alive', 'Poor', '40.80170032, -73.96063153')
# (198527, '10026', 'Quercus phellos', 'Alive', 'Good', '40.8016628, -73.96054285')
# (211530, '10025', 'Tilia americana', 'Alive', 'Fair', '40.80313278, -73.96723047')
# (187706, '10026', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80662798, -73.95386196')
# (187705, '10026', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80656162, -73.95391003')
# (187709, '10026', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80684343, -73.95370588')
# (187708, '10026', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80677466, -73.9537557')
# (231985, '10026', 'Quercus palustris', 'Alive', 'Good', '40.80467705, -73.95575275')
# (247595, '10026', 'Quercus palustris', 'Alive', 'Good', '40.80594216, -73.95481493')
# (187704, '10026', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80651209, -73.95394592')
# (209967, '10025', 'Quercus palustris', 'Alive', 'Good', '40.8068621, -73.96473823')
# (231988, '10026', 'Quercus palustris', 'Alive', 'Good', '40.80491062, -73.95630759')
# (247597, '10026', 'Quercus palustris', 'Alive', 'Good', '40.80603376, -73.95503307')
# (232014, '10026', 'Quercus palustris', 'Alive', 'Good', '40.80469154, -73.95627336')
# (232013, '10026', 'Quercus palustris', 'Alive', 'Good', '40.80477139, -73.95646291')
# (214709, '10025', 'Quercus palustris', 'Alive', 'Fair', '40.80627157, -73.96493688')
# (214711, '10025', 'Quercus palustris', 'Alive', 'Fair', '40.80644846, -73.96480552')
# (232015, '10026', 'Quercus palustris', 'Alive', 'Good', '40.80458781, -73.95609793')
# (214707, '10025', 'Quercus palustris', 'Alive', 'Fair', '40.80615922, -73.96502032')
# (187707, '10026', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80669146, -73.95381597')
# (211531, '10025', 'Ulmus parvifolia', 'Alive', 'Fair', '40.80322812, -73.96716178')
# (188999, '10027', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80858195, -73.95912544')
# (247580, '10026', 'Zelkova serrata', 'Alive', 'Good', '40.80396884, -73.9562875')
# (189000, '10027', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80866339, -73.95931797')
# (225210, '10026', 'Tilia americana', 'Alive', 'Fair', '40.80282441, -73.95832957')
# (188997, '10027', 'Koelreuteria paniculata', 'Alive', 'Good', '40.80848355, -73.95889283')
# (225211, '10026', 'Tilia americana', 'Alive', 'Fair', '40.80289413, -73.95827902')
# (222723, '10025', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80166829, -73.9644755')
# (222718, '10025', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80135158, -73.96372447')
# (240333, '10027', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80745941, -73.95868135')
# (211608, '10025', 'Pyrus calleryana', 'Alive', 'Good', '40.80258619, -73.96425696')
# (240334, '10027', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80750379, -73.95878609')
# (207295, '10026', 'Pyrus calleryana', 'Alive', 'Good', '40.80460094, -73.95722618')
# (207210, '10026', 'Koelreuteria paniculata', 'Alive', 'Good', '40.80295518, -73.95804054')
# (247598, '10026', 'Quercus palustris', 'Alive', 'Good', '40.80606324, -73.95510326')
# (214710, '10025', 'Quercus palustris', 'Alive', 'Fair', '40.80638153, -73.96485522')
# (198520, '10025', 'Platanus x acerifolia', 'Alive', 'Fair', '40.80198651, -73.96133176')
# (247578, '10026', 'Quercus palustris', 'Alive', 'Good', '40.80404415, -73.95646631')
# (240336, '10027', 'Ginkgo biloba', 'Alive', 'Good', '40.80776072, -73.95939246')
# (222719, '10025', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80139047, -73.96381669')
# (240335, '10027', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80755138, -73.9588984')
# (225212, '10026', 'Tilia americana', 'Alive', 'Good', '40.80296072, -73.95823075')
# (240339, '10027', 'Ginkgo biloba', 'Alive', 'Good', '40.80790803, -73.95974013')
# (217549, '10025', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80155763, -73.96815272')
# (240647, '10027', 'Tilia americana', 'Alive', 'Good', '40.80842575, -73.95974356')
# (211610, '10025', 'Ulmus parvifolia', 'Alive', 'Good', '40.80270875, -73.96416')
# (211612, '10025', 'Ulmus parvifolia', 'Alive', 'Good', '40.80280948, -73.96409471')
# (240338, '10027', 'Ginkgo biloba', 'Alive', 'Good', '40.80785456, -73.95961393')
# (217548, '10025', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.801582, -73.96821946')
# (240340, '10027', 'Tilia americana', 'Alive', 'Poor', '40.80796177, -73.95986696')
# (247575, '10026', 'Zelkova serrata', 'Alive', 'Good', '40.80424321, -73.95693893')
# (247577, '10026', 'Zelkova serrata', 'Alive', 'Good', '40.80413224, -73.95667545')
# (211611, '10025', 'Ulmus parvifolia', 'Alive', 'Good', '40.80276468, -73.9641482')
# (211609, '10025', 'Ulmus parvifolia', 'Alive', 'Good', '40.802649, -73.96420727')
# (247696, '10026', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80646659, -73.95606628')
# (247584, '10026', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80550447, -73.95771552')
# (247582, '10026', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.8055934, -73.95792653')
# (214746, '10027', 'Gleditsia triacanthos var. inermis', 'Alive', 'Fair', '40.80845158, -73.96334711')
# (247585, '10026', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80536574, -73.95738638')
# (247587, '10026', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80521024, -73.95701744')
# (225164, '10026', 'Tilia americana', 'Alive', 'Good', '40.80151023, -73.95824443')
# (139763, '10026', 'Magnolia', 'Alive', 'Good', '40.8033235, -73.95670419')
# (139765, '10026', 'Magnolia', 'Alive', 'Good', '40.80347864, -73.95707215')
# (225162, '10026', 'Styphnolobium japonicum', 'Alive', 'Good', '40.80136473, -73.95789918')
# (210159, '10025', 'Magnolia', 'Alive', 'Good', '40.80529396, -73.96588575')
# (210172, '10025', 'Magnolia', 'Alive', 'Good', '40.8049337, -73.96614578')
# (225163, '10026', 'Styphnolobium japonicum', 'Alive', 'Good', '40.80143848, -73.95807417')
# (247609, '10026', 'Platanus x acerifolia', 'Alive', 'Good', '40.80734716, -73.95522178')
# (225166, '10026', 'Zelkova serrata', 'Alive', 'Good', '40.80175889, -73.95883448')
# (225097, '10026', 'Quercus rubra', 'Alive', 'Fair', '40.80154447, -73.95858405')
# (211613, '10025', 'Ulmus parvifolia', 'Alive', 'Poor', '40.80283128, -73.96401355')
# (225099, '10026', 'Quercus rubra', 'Alive', 'Good', '40.80145578, -73.95837288')
# (225096, '10026', 'Ulmus parvifolia', 'Alive', 'Good', '40.80162519, -73.95877625')
# (247769, '10026', 'Zelkova serrata', 'Alive', 'Good', '40.80544538, -73.95805203')
# (247773, '10026', 'Ginkgo biloba', 'Alive', 'Poor', '40.80530224, -73.95771454')
# (196587, '10025', 'Fraxinus pennsylvanica', 'Alive', 'Good', '40.8071505, -73.96708925')
# (247579, '10026', 'Platanus x acerifolia', 'Alive', 'Fair', '40.80400317, -73.956369')
# (198521, '10026', 'Ulmus americana', 'Alive', 'Good', '40.8017988, -73.96079377')
# (198528, '10026', 'Quercus phellos', 'Alive', 'Good', '40.80162609, -73.96045606')
# (225042, '10025', 'Pyrus calleryana', 'Alive', 'Poor', '40.80080587, -73.96185133')
# (225044, '10025', 'Styphnolobium japonicum', 'Alive', 'Good', '40.80094182, -73.96175166')
# (247596, '10026', 'Quercus palustris', 'Alive', 'Fair', '40.80600668, -73.95496858')
# (214708, '10025', 'Quercus palustris', 'Alive', 'Fair', '40.80622137, -73.96497416')
# (247663, '10026', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80556151, -73.95652006')
# (225201, '10026', 'Tilia americana', 'Alive', 'Good', '40.80198519, -73.95769224')
# (247581, '10026', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80393158, -73.95619904')
# (255376, '10025', 'Gleditsia triacanthos var. inermis', 'Alive', 'Fair', '40.80429848, -73.96317822')
# (225045, '10025', 'Styphnolobium japonicum', 'Alive', 'Good', '40.80099025, -73.96171615')
# (225198, '10026', 'Tilia americana', 'Alive', 'Good', '40.8021487, -73.9580801')
# (225200, '10026', 'Tilia americana', 'Alive', 'Good', '40.80201342, -73.9577592')
# (222720, '10025', 'Styphnolobium japonicum', 'Alive', 'Good', '40.80146665, -73.96399735')
# (240568, '10027', 'Styphnolobium japonicum', 'Alive', 'Good', '40.8078211, -73.96017986')
# (240337, '10027', 'Ginkgo biloba', 'Alive', 'Fair', '40.80780751, -73.95950288')
# (255382, '10025', 'Ginkgo biloba', 'Alive', 'Fair', '40.80455077, -73.96377474')
# (255383, '10025', 'Ginkgo biloba', 'Alive', 'Fair', '40.80458547, -73.9638568')
# (255091, '10025', 'Ginkgo biloba', 'Alive', 'Fair', '40.80510329, -73.96482239')
# (247781, '10026', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80667893, -73.95729408')
# (247782, '10026', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.8065188, -73.95741011')
# (240668, '10027', 'Ulmus americana', 'Alive', 'Fair', '40.80885798, -73.95942964')
# (255089, '10025', 'Ginkgo biloba', 'Alive', 'Fair', '40.80518181, -73.96500878')
# (255090, '10025', 'Ginkgo biloba', 'Alive', 'Poor', '40.80514055, -73.96491084')
# (240669, '10027', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80903293, -73.95930258')
# (255399, '10025', 'Ginkgo biloba', 'Alive', 'Good', '40.80525021, -73.9654286')
# (255096, '10025', 'Ginkgo biloba', 'Alive', 'Poor', '40.80482913, -73.96417161')
# (255097, '10025', 'Gleditsia triacanthos var. inermis', 'Alive', 'Fair', '40.80457759, -73.96357455')
# (255095, '10025', 'Tilia americana', 'Alive', 'Fair', '40.80485974, -73.96424427')
# (261733, '10027', 'Ginkgo biloba', 'Alive', 'Good', '40.81242157, -73.96235372')
# (247676, '10026', 'Ginkgo biloba', 'Alive', 'Good', '40.80447083, -73.95814907')
# (255087, '10025', 'Ginkgo biloba', 'Alive', 'Fair', '40.80534816, -73.96540367')
# (255088, '10025', 'Ginkgo biloba', 'Alive', 'Fair', '40.80523105, -73.96512567')
# (261736, '10027', 'Ginkgo biloba', 'Alive', 'Good', '40.81258463, -73.96273867')
# (255389, '10025', 'Ginkgo biloba', 'Alive', 'Poor', '40.80482708, -73.96442807')
# (255390, '10025', 'Ginkgo biloba', 'Alive', 'Poor', '40.80484977, -73.96448173')
# (247603, '10026', 'Quercus palustris', 'Alive', 'Good', '40.80621976, -73.955476')
# (247602, '10026', 'Quercus palustris', 'Alive', 'Good', '40.80618259, -73.95538748')
# (261914, '10027', 'Zelkova serrata', 'Alive', 'Good', '40.81232302, -73.96096629')
# (261915, '10027', 'Pyrus calleryana', 'Alive', 'Good', '40.8124746, -73.96085528')
# (261916, '10027', 'Pyrus calleryana', 'Alive', 'Good', '40.81264441, -73.96073091')
# (211826, '10025', 'Ginkgo biloba', 'Alive', 'Fair', '40.80168562, -73.96765911')
# (261748, '10027', 'Ginkgo biloba', 'Alive', 'Good', '40.81398893, -73.96007015')
# (188717, '10027', 'Quercus bicolor', 'Alive', 'Good', '40.80828717, -73.95789547')
# (247871, '10026', 'Pyrus calleryana', 'Alive', 'Good', '40.80606883, -73.95706603')
# (138432, '10026', 'Ulmus pumila', 'Alive', 'Good', '40.804327, -73.96012385')
# (218308, '10025', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80363064, -73.96743808')
# (218304, '10025', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80391476, -73.96811421')
# (261875, '10027', 'Tilia cordata', 'Alive', 'Fair', '40.81211584, -73.96162515')
# (193165, '10025', 'Celtis occidentalis', 'Alive', 'Fair', '40.80133096, -73.96198359')
# (218307, '10025', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80367142, -73.96753512')
# (247673, '10026', 'Quercus bicolor', 'Alive', 'Good', '40.80413962, -73.95812896')
# (247671, '10026', 'Quercus bicolor', 'Alive', 'Good', '40.80400691, -73.9581209')
# (211638, '10025', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.8035153, -73.96359084')
# (261919, '10027', 'Ginkgo biloba', 'Alive', 'Fair', '40.81293366, -73.96051906')
# (261921, '10027', 'Ginkgo biloba', 'Alive', 'Good', '40.81311282, -73.96038784')
# (218187, '10025', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.8051629, -73.96618859')
# (271118, '10026', 'Ulmus parvifolia', 'Alive', 'Good', '40.80531813, -73.95520931')
# (211828, '10025', 'Ulmus americana', 'Alive', 'Good', '40.80187119, -73.96764638')
# (218305, '10025', 'Ulmus americana', 'Alive', 'Fair', '40.80382178, -73.96789294')
# (218235, '10025', 'Pyrus calleryana', 'Alive', 'Poor', '40.8053373, -73.96732243')
# (271030, '10026', 'Ostrya virginiana', 'Alive', 'Good', '40.80612215, -73.95592012')
# (247742, '10026', 'Pyrus calleryana', 'Alive', 'Good', '40.8061128, -73.95743732')
# (247743, '10026', 'Pyrus calleryana', 'Alive', 'Good', '40.80615271, -73.95753211')
# (271029, '10026', 'Ostrya virginiana', 'Alive', 'Good', '40.80618129, -73.95587725')
# (247741, '10026', 'Pyrus calleryana', 'Alive', 'Good', '40.80607237, -73.95734127')
# (247710, '10026', 'Zelkova serrata', 'Alive', 'Good', '40.80540337, -73.95816525')
# (247929, '10026', 'Zelkova serrata', 'Alive', 'Good', '40.80742358, -73.95468468')
# (270985, '10026', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80678073, -73.95707789')
# (211487, '10025', 'Ginkgo biloba', 'Alive', 'Good', '40.80079478, -73.96557276')
# (270984, '10026', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80674, -73.9569808')
# (271119, '10026', 'Ulmus parvifolia', 'Alive', 'Fair', '40.80528404, -73.95512762')
# (271113, '10026', 'Pyrus calleryana', 'Alive', 'Good', '40.80549403, -73.95570198')
# (247735, '10026', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80578796, -73.95666574')
# (261874, '10027', 'Tilia cordata', 'Alive', 'Good', '40.81215755, -73.96172317')
# (255098, '10025', 'Robinia pseudoacacia', 'Alive', 'Fair', '40.80453634, -73.96347662')
# (247978, '10026', 'Zelkova serrata', 'Alive', 'Good', '40.80706198, -73.95523981')
# (211488, '10025', 'Quercus palustris', 'Alive', 'Good', '40.80089474, -73.9654994')
# (247872, '10026', 'Ulmus americana', 'Alive', 'Good', '40.80603029, -73.95697521')
# (247702, '10026', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80675398, -73.95674955')
# (211825, '10025', 'Ginkgo biloba', 'Alive', 'Good', '40.80161737, -73.96766379')
# (261749, '10027', 'Styphnolobium japonicum', 'Alive', 'Good', '40.81403467, -73.96017886')
# (247531, '10026', 'Tilia americana', 'Alive', 'Fair', '40.80774728, -73.95546355')
# (247700, '10026', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80667981, -73.9565732')
# (247586, '10026', 'Styphnolobium japonicum', 'Alive', 'Good', '40.80528293, -73.9571899')
# (247449, '10026', 'Styphnolobium japonicum', 'Alive', 'Good', '40.80458354, -73.9577434')
# (139769, '10026', 'Magnolia', 'Alive', 'Good', '40.80369063, -73.95757498')
# (139708, '10026', 'Betula papyrifera', 'Alive', 'Poor', '40.80286321, -73.95755943')
# (210170, '10025', 'Magnolia', 'Alive', 'Good', '40.80496066, -73.96612632')
# (261809, '10027', 'Ginkgo biloba', 'Alive', 'Good', '40.81387771, -73.96081328')
# (218229, '10025', 'Styphnolobium japonicum', 'Alive', 'Good', '40.80513326, -73.96684146')
# (218231, '10025', 'Styphnolobium japonicum', 'Alive', 'Fair', '40.80520712, -73.96701555')
# (247450, '10026', 'Styphnolobium japonicum', 'Alive', 'Good', '40.80454457, -73.95765041')
# (209959, '10025', 'Magnolia', 'Alive', 'Good', '40.80717733, -73.96455139')
# (261811, '10027', 'Ginkgo biloba', 'Alive', 'Good', '40.81370763, -73.96093774')
# (247706, '10026', 'Ulmus americana', 'Alive', 'Good', '40.80503169, -73.95818832')
# (247529, '10026', 'Tilia americana', 'Alive', 'Fair', '40.80785502, -73.95571866')
# (261810, '10027', 'Ginkgo biloba', 'Alive', 'Fair', '40.81380982, -73.96086296')
# (247977, '10026', 'Zelkova serrata', 'Alive', 'Good', '40.80713391, -73.95518707')
# (247530, '10026', 'Tilia americana', 'Alive', 'Fair', '40.80780035, -73.95558921')
# (139768, '10026', 'Magnolia', 'Alive', 'Good', '40.80364642, -73.95747012')
# (247931, '10026', 'Cercidiphyllum japonicum', 'Alive', 'Fair', '40.80601083, -73.95619696')
# (214760, '10027', 'Taxodium distichum', 'Alive', 'Good', '40.80998835, -73.96222719')
# (247658, '10026', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80645227, -73.95587085')
# (261813, '10027', 'Ginkgo biloba', 'Alive', 'Good', '40.81350708, -73.9610845')
# (247976, '10026', 'Zelkova serrata', 'Alive', 'Good', '40.8071953, -73.95514207')
# (247833, '10026', 'Quercus palustris', 'Alive', 'Good', '40.80723538, -73.95688821')
# (247923, '10026', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80702848, -73.95375786')
# ...
# (178538, '10026', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80487574, -73.95834401')
# (178558, '10026', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.808051, -73.95656183')
# (178561, '10026', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80853139, -73.95621147')
# (178537, '10026', 'Platanus x acerifolia', 'Alive', 'Good', '40.80465608, -73.95832506')
# (178524, '10026', 'Platanus x acerifolia', 'Alive', 'Good', '40.80174584, -73.9593083')
# (186786, '10025', 'Quercus palustris', 'Alive', 'Fair', '40.80392523, -73.96589577')
# (138618, '10027', 'Fraxinus pennsylvanica', 'Alive', 'Fair', '40.80915328, -73.95463122')
# (186923, '10025', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80422961, -73.96496048')
# (186921, '10025', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.8043848, -73.96532965')
# (186774, '10025', 'Quercus palustris', 'Alive', 'Good', '40.80333069, -73.96448135')
# (135362, '10027', 'Styphnolobium japonicum', 'Alive', 'Good', '40.81015925, -73.95897534')
# (188548, '10025', 'Platanus x acerifolia', 'Alive', 'Good', '40.80253159, -73.96090435')
# (188551, '10025', 'Platanus x acerifolia', 'Alive', 'Good', '40.80282891, -73.96080159')
# (188553, '10025', 'Platanus x acerifolia', 'Alive', 'Good', '40.8031042, -73.96070645')
# (188716, '10027', 'Ulmus americana', 'Alive', 'Fair', '40.80819544, -73.9579428')
# (186784, '10025', 'Quercus palustris', 'Alive', 'Good', '40.80381177, -73.96562584')
# (178568, '10026', 'Pyrus calleryana', 'Alive', 'Good', '40.810065, -73.95509291')
# (186924, '10025', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80416411, -73.96480466')
# (189183, '10027', 'Ginkgo biloba', 'Alive', 'Good', '40.80824407, -73.95858939')
# (188557, '10025', 'Platanus x acerifolia', 'Alive', 'Good', '40.80351728, -73.96056368')
# (186918, '10025', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80455779, -73.96574117')
# (188556, '10025', 'Platanus x acerifolia', 'Alive', 'Good', '40.80341587, -73.96059873')
# (186929, '10025', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.8037958, -73.96392853')
# (135346, '10027', 'Acer nigrum', 'Alive', 'Good', '40.81028771, -73.95538132')
# (113413, '10027', 'Acer nigrum', 'Alive', 'Good', '40.80828704, -73.95479713')
# (186925, '10025', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80410578, -73.96466591')
# (186930, '10025', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80372883, -73.96376924')
# (186931, '10025', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80368658, -73.96366873')
# (186927, '10025', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80395657, -73.96431097')
# (113440, '10027', 'Taxodium distichum', 'Alive', 'Fair', '40.80931336, -73.95334716')
# (113441, '10027', 'Taxodium distichum', 'Alive', 'Good', '40.8093473, -73.95343305')
# (188696, '10027', 'Ulmus americana', 'Alive', 'Fair', '40.80790111, -73.95813958')
# (135492, '10027', 'Styphnolobium japonicum', 'Alive', 'Good', '40.81162707, -73.96081817')
# (186919, '10025', 'Quercus bicolor', 'Alive', 'Good', '40.8045004, -73.96560463')
# (187148, '10027', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.806476, -73.96143354')
# (188718, '10027', 'Ginkgo biloba', 'Alive', 'Good', '40.80843845, -73.95781741')
# (188835, '10027', 'Ginkgo biloba', 'Alive', 'Good', '40.80911741, -73.95896487')
# (187152, '10027', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80829464, -73.96010594')
# (187146, '10027', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.8060154, -73.96176977')
# (187147, '10027', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80635431, -73.96152237')
# (187153, '10027', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80857355, -73.95990233')
# (187154, '10027', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80864579, -73.95984959')
# (135527, '10027', 'Styphnolobium japonicum', 'Alive', 'Good', '40.81087955, -73.95869538')
# (135521, '10027', 'Styphnolobium japonicum', 'Alive', 'Good', '40.81138187, -73.95988605')
# (188695, '10027', 'Ulmus americana', 'Alive', 'Good', '40.80780836, -73.95820773')
# (198516, '10025', 'Quercus phellos', 'Alive', 'Good', '40.80214639, -73.96171194')
# (178554, '10026', 'Pyrus calleryana', 'Alive', 'Good', '40.80754301, -73.95693233')
# (178533, '10026', 'Platanus x acerifolia', 'Alive', 'Good', '40.80357339, -73.9582705')
# (203951, '10025', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80656578, -73.96107442')
# (135440, '10027', 'Prunus serotina', 'Alive', 'Good', '40.80978437, -73.95418857')
# (189179, '10027', 'Styphnolobium japonicum', 'Alive', 'Good', '40.8084577, -73.95909727')
# (178548, '10026', 'Acer platanoides', 'Alive', 'Good', '40.80673059, -73.95752483')
# (198504, '10025', 'Quercus palustris', 'Alive', 'Good', '40.80289767, -73.96349849')
# (198506, '10025', 'Quercus palustris', 'Alive', 'Good', '40.80275387, -73.96315654')
# (204077, '10025', 'Pyrus calleryana', 'Alive', 'Fair', '40.80518753, -73.96139788')
# (203889, '10025', 'Zelkova serrata', 'Alive', 'Fair', '40.80595424, -73.96126539')
# (122006, '10025', 'Quercus acutissima', 'Alive', 'Fair', '40.80082766, -73.96443635')
# (188992, '10027', 'Ginkgo biloba', 'Alive', 'Good', '40.80822321, -73.95827737')
# (203885, '10025', 'Quercus phellos', 'Alive', 'Fair', '40.80564591, -73.96052803')
# (198519, '10025', 'Platanus x acerifolia', 'Alive', 'Fair', '40.8020398, -73.96145848')
# (203888, '10025', 'Zelkova serrata', 'Alive', 'Fair', '40.80590977, -73.96115906')
# (203890, '10025', 'Zelkova serrata', 'Alive', 'Good', '40.80598414, -73.96133691')
# (187101, '10025', 'Quercus palustris', 'Alive', 'Good', '40.8050214, -73.96249825')
# (196545, '10027', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80896048, -73.96573819')
# (189407, '10027', 'Ginkgo biloba', 'Alive', 'Fair', '40.80771705, -73.95902823')
# (189408, '10027', 'Ginkgo biloba', 'Alive', 'Fair', '40.80776944, -73.95915232')
# (186932, '10025', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80364685, -73.96357423')
# (138449, '10026', 'Tilia cordata', 'Alive', 'Good', '40.80237457, -73.9607877')
# (113386, '10027', 'Styphnolobium japonicum', 'Alive', 'Good', '40.80835822, -73.95473725')
# (121402, '10025', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80145621, -73.96110802')
# (121478, '10025', 'Quercus shumardii', 'Alive', 'Good', '40.80230748, -73.96251868')
# (121473, '10025', 'Quercus shumardii', 'Alive', 'Good', '40.80205789, -73.96191982')
# (107043, '10025', 'Koelreuteria paniculata', 'Alive', 'Good', '40.80278142, -73.96516476')
# (113320, '10027', 'Styphnolobium japonicum', 'Alive', 'Good', '40.80711007, -73.95368801')
# (135480, '10027', 'Styphnolobium japonicum', 'Alive', 'Good', '40.81087773, -73.95903947')
# (121995, '10025', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80063122, -73.96422718')
# (135324, '10027', 'Ginkgo biloba', 'Alive', 'Good', '40.80968799, -73.95784972')
# (121996, '10025', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80065727, -73.96428913')
# (121993, '10025', 'Ginkgo biloba', 'Alive', 'Fair', '40.80056478, -73.96406916')
# (138443, '10026', 'Tilia cordata', 'Alive', 'Poor', '40.80309687, -73.96054211')
# (138546, '10027', 'Quercus palustris', 'Alive', 'Good', '40.80862008, -73.95336955')
# (121476, '10025', 'Quercus acutissima', 'Alive', 'Good', '40.80220374, -73.96226976')
# (121997, '10025', 'Tilia americana', 'Alive', 'Good', '40.8007168, -73.96443071')
# (121998, '10025', 'Gleditsia triacanthos var. inermis', 'Alive', 'Fair', '40.80079653, -73.96462033')
# (138773, '10027', 'Tilia tomentosa', 'Alive', 'Good', '40.80955004, -73.95389487')
# (138548, '10027', 'Quercus palustris', 'Alive', 'Good', '40.80870029, -73.95355884')
# (113324, '10027', 'Tilia cordata', 'Alive', 'Good', '40.80733823, -73.95423194')
# (113326, '10027', 'Tilia cordata', 'Alive', 'Good', '40.80749873, -73.95461459')
# (138766, '10027', 'Quercus rubra', 'Alive', 'Good', '40.80990569, -73.95474396')
# (139747, '10026', 'Magnolia', 'Alive', 'Good', '40.80320083, -73.95666972')
# (76476, '10025', 'Prunus virginiana', 'Alive', 'Good', '40.8055743, -73.96758786')
# (139744, '10026', 'Tilia cordata', 'Alive', 'Fair', '40.8033798, -73.95709339')
# (138770, '10027', 'Fraxinus pennsylvanica', 'Alive', 'Good', '40.80972919, -73.95432257')
# (142443, '10025', 'Ulmus americana', 'Alive', 'Good', '40.80275062, -73.967662')
# (122001, '10025', 'Ostrya virginiana', 'Alive', 'Good', '40.80098363, -73.96506531')
# (138768, '10027', 'Quercus rubra', 'Alive', 'Good', '40.80983785, -73.95458198')
# (135513, '10027', 'Ginkgo biloba', 'Alive', 'Good', '40.81173761, -73.96072932')
# (135514, '10027', 'Ginkgo biloba', 'Alive', 'Good', '40.81169497, -73.96062826')
# (135326, '10027', 'Ulmus parvifolia', 'Alive', 'Good', '40.80961219, -73.95766959')
# (135329, '10027', 'Ulmus parvifolia', 'Alive', 'Good', '40.80950715, -73.95741994')
# (113389, '10027', 'Tilia cordata', 'Alive', 'Good', '40.80858908, -73.95528336')
# (113325, '10027', 'Tilia cordata', 'Alive', 'Good', '40.80736476, -73.95429519')
# (122000, '10025', 'Ostrya virginiana', 'Alive', 'Good', '40.80094828, -73.96498125')
# (135443, '10027', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80962868, -73.95381891')
# (135519, '10027', 'Ginkgo biloba', 'Alive', 'Good', '40.81145781, -73.96006608')
# (159233, '10025', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80059356, -73.9654574')
# (135482, '10027', 'Ginkgo biloba', 'Alive', 'Good', '40.81101083, -73.9593554')
# (158882, '10025', 'Ulmus parvifolia', 'Alive', 'Poor', '40.80135814, -73.96489404')
# (107031, '10025', 'Gymnocladus dioicus', 'Alive', 'Good', '40.80325785, -73.96629364')
# (158881, '10025', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80148862, -73.96479852')
# (121475, '10025', 'Quercus shumardii', 'Alive', 'Good', '40.80216111, -73.96216747')
# (135261, '10027', 'Pyrus calleryana', 'Alive', 'Good', '40.80929807, -73.95737719')
# (76152, '10027', 'Robinia pseudoacacia', 'Alive', 'Fair', '40.81000706, -73.96482008')
# (121384, '10025', 'Zelkova serrata', 'Alive', 'Good', '40.80078023, -73.96160334')
# (140259, '10025', 'Ginkgo biloba', 'Alive', 'Good', '40.8007921, -73.95912671')
# (135491, '10027', 'Ulmus parvifolia', 'Alive', 'Good', '40.81155387, -73.9606444')
# (138387, '10026', 'Gymnocladus dioicus', 'Alive', 'Good', '40.81049588, -73.95782745')
# (138402, '10026', 'Gymnocladus dioicus', 'Alive', 'Good', '40.80820317, -73.95776524')
# (135289, '10027', 'Quercus acutissima', 'Alive', 'Good', '40.80956047, -73.95780688')
# (159210, '10025', 'Platanus x acerifolia', 'Alive', 'Good', '40.80134737, -73.96404187')
# (138619, '10027', 'Fraxinus pennsylvanica', 'Alive', 'Good', '40.80920923, -73.95476387')
# (135365, '10027', 'Styphnolobium japonicum', 'Alive', 'Good', '40.81068596, -73.96022667')
# (142418, '10025', 'Crataegus', 'Alive', 'Fair', '40.80303996, -73.96753089')
# (6754, '10026', 'Magnolia', 'Alive', 'Poor', '40.80324775, -73.9561045')
# (138418, '10026', 'Ulmus pumila', 'Alive', 'Good', '40.8062245, -73.9591763')
# (138386, '10026', 'Gymnocladus dioicus', 'Alive', 'Good', '40.81054458, -73.95793976')
# (138404, '10026', 'Gymnocladus dioicus', 'Alive', 'Good', '40.80803963, -73.95785073')
# (178563, '10026', 'Tilia cordata', 'Alive', 'Fair', '40.80875658, -73.95604723')
# (135526, '10027', 'Ginkgo biloba', 'Alive', 'Good', '40.81091819, -73.95878697')
# (135523, '10027', 'Ulmus parvifolia', 'Alive', 'Good', '40.81105943, -73.95912175')
# (135524, '10027', 'Ulmus parvifolia', 'Alive', 'Good', '40.81101546, -73.95901753')
# (178541, '10026', 'Quercus palustris', 'Alive', 'Good', '40.80532941, -73.95837117')
# (178542, '10026', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80542985, -73.95836085')
# (178527, '10026', 'Platanus x acerifolia', 'Alive', 'Good', '40.80266384, -73.9586402')
# (178536, '10026', 'Platanus x acerifolia', 'Alive', 'Good', '40.80447745, -73.95831772')
# (178562, '10026', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80862886, -73.95614038')
# (135520, '10027', 'Chionanthus retusus', 'Alive', 'Good', '40.81141118, -73.95995554')
# (189181, '10027', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80839349, -73.95894462')
# (186926, '10025', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80403031, -73.96448638')
# (186928, '10025', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80386914, -73.964103')
# (186922, '10025', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80429738, -73.96512168')
# (188549, '10025', 'Platanus x acerifolia', 'Alive', 'Good', '40.80263804, -73.96086755')
# (178565, '10026', 'Platanus x acerifolia', 'Alive', 'Good', '40.80922376, -73.95570649')
# (188555, '10025', 'Platanus x acerifolia', 'Alive', 'Good', '40.80330172, -73.96063819')
# (178559, '10026', 'Platanus x acerifolia', 'Alive', 'Good', '40.80821953, -73.95643892')
# (178560, '10026', 'Platanus x acerifolia', 'Alive', 'Good', '40.80844088, -73.95627748')
# (186782, '10025', 'Quercus palustris', 'Alive', 'Good', '40.80370694, -73.96537646')
# (193099, '10025', 'Zelkova serrata', 'Alive', 'Good', '40.80319062, -73.96639536')
# (189180, '10027', 'Tilia tomentosa', 'Alive', 'Fair', '40.808423, -73.95901478')
# (193096, '10025', 'Pyrus calleryana', 'Alive', 'Good', '40.80333276, -73.9667315')
# (186775, '10025', 'Pyrus calleryana', 'Alive', 'Fair', '40.80338782, -73.96461726')
# (178567, '10026', 'Pyrus calleryana', 'Alive', 'Good', '40.80985995, -73.95524247')
# (178526, '10026', 'Tilia cordata', 'Alive', 'Fair', '40.80215896, -73.95900764')
# (186772, '10025', 'Quercus palustris', 'Alive', 'Good', '40.80322599, -73.96423229')
# (186781, '10025', 'Quercus palustris', 'Alive', 'Fair', '40.80366602, -73.96527911')
# (138401, '10026', 'Gymnocladus dioicus', 'Alive', 'Good', '40.80828075, -73.95772482')
# (193102, '10025', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80306409, -73.96609615')
# (188991, '10027', 'Ginkgo biloba', 'Alive', 'Fair', '40.80818289, -73.95818206')
# (135522, '10027', 'Styphnolobium japonicum', 'Alive', 'Good', '40.81110739, -73.95923545')
# (178566, '10026', 'Pyrus calleryana', 'Alive', 'Good', '40.8096871, -73.95536854')
# (187150, '10027', 'Pyrus calleryana', 'Alive', 'Good', '40.80706261, -73.96100533')
# (188694, '10027', 'Ulmus americana', 'Alive', 'Fair', '40.80769932, -73.95828785')
# (187063, '10025', 'Platanus x acerifolia', 'Alive', 'Good', '40.80475782, -73.96268758')
# (186789, '10025', 'Ginkgo biloba', 'Alive', 'Good', '40.80410489, -73.96633325')
# (204100, '10025', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80593058, -73.96154703')
# (204104, '10025', 'Ginkgo biloba', 'Alive', 'Good', '40.8056242, -73.96178061')
# (186787, '10025', 'Ginkgo biloba', 'Alive', 'Good', '40.80405702, -73.96620931')
# (178551, '10026', 'Pyrus calleryana', 'Alive', 'Good', '40.80721218, -73.9571736')
# (198517, '10025', 'Platanus x acerifolia', 'Alive', 'Fair', '40.80210559, -73.96161492')
# (204079, '10025', 'Pyrus calleryana', 'Alive', 'Fair', '40.80532499, -73.96172877')
# (188836, '10027', 'Pyrus calleryana', 'Alive', 'Fair', '40.8090595, -73.95882911')
# (203955, '10025', 'Ginkgo biloba', 'Alive', 'Good', '40.806253, -73.96131649')
# (204078, '10025', 'Pyrus calleryana', 'Alive', 'Good', '40.80522808, -73.9614955')
# (142372, '10025', 'Crataegus', 'Alive', 'Good', '40.80371461, -73.96704423')
# (203952, '10025', 'Gleditsia triacanthos var. inermis', 'Alive', 'Good', '40.80648344, -73.96113814')
# (188994, '10027', 'Ginkgo biloba', 'Alive', 'Fair', '40.80830091, -73.95846106')
# (189186, '10027', 'Ginkgo biloba', 'Alive', 'Poor', '40.80808229, -73.95820478')
# (203886, '10025', 'Quercus phellos', 'Alive', 'Good', '40.80568587, -73.9606236')
# (186783, '10025', 'Quercus coccinea', 'Alive', 'Good', '40.80376221, -73.96550795')
# (198513, '10025', 'Quercus rubra', 'Alive', 'Good', '40.80234813, -73.96219168')
# (203997, '10025', 'Platanus x acerifolia', 'Alive', 'Good', '40.80499024, -73.96065411')
# (203998, '10025', 'Platanus x acerifolia', 'Alive', 'Good', '40.8049499, -73.96055964')

# %% [markdown]
# ## Part 4: Visualizing the Data

# %% [markdown]
# ### Visualization 1

# %%
def plot_visual_1(dataframe):
    """This function helps to set up the visual plot for any dataframes of V1"""
    figure, axes = plt.subplots(figsize=(12, 6))

    dataframe.plot(x="time", y="complaint_count",kind='line', color='green', ax=axes)
    axes.set_title('Complaints per Day')
    axes.set_xlabel('Date')
    axes.set_ylabel('Complaints')
    figure.show()

def get_data_for_visual_1():
    # Define the SQL query
    query = """
        SELECT
            "Time" AS time,
            COUNT(*) AS complaint_count
        FROM
            "public"."NYC_311"
        WHERE
            "Time" BETWEEN '2022-10-01' AND '2023-09-30'
        GROUP BY
            "Time";
    """

    df = pd.read_sql_query(query, engine)
    return df

# %% [markdown]
# _Here we call the function and get the result of a diagram showing complaints per day_

# %%
some_dataframe = get_data_for_visual_1()
plot_visual_1(some_dataframe)
# Out:
# C:\Users\86159\AppData\Local\Temp\ipykernel_16448\48076071.py:9: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   figure.show()

# %% [markdown]
# ### Visualization 2

# %%
def plot_visual_2(dataframe):
    """This function helps to set up the visual plot for any data frames of V2"""
    plt.figure(figsize=(12, 6))
    plt.bar(dataframe["ComplaintType"], dataframe["complaint_count"], color='green')
    plt.title('Top 10 Complaints in ZipCode 10027')
    plt.xlabel('Complaint Type')
    plt.ylabel('Complaint Count')
    plt.xticks(rotation=-45, ha='center')
    plt.tight_layout()
    plt.show()

def get_data_for_visual_2():
    # Define the SQL query
    query = """
        SELECT
            "ComplaintType",
            COUNT(*) AS complaint_count
        FROM
            "public"."NYC_311"
        WHERE
            "ZipCode" = '10027'
            AND "Time" BETWEEN '2018-10-01' AND '2023-09-30'
        GROUP BY
            "ComplaintType"
        ORDER BY
            complaint_count DESC
        LIMIT 10
    """

    df = pd.read_sql_query(query, engine)
    return df

# %% [markdown]
# _Call the function and get an image of top 10 complaints in area 10027_

# %%
some_dataframe = get_data_for_visual_2()
plot_visual_2(some_dataframe)

# %% [markdown]
# ### Visualization 3

# %%
def get_data_for_visual_3():
    # Define the SQL queries
    query_rent = """
        SELECT
            "ZipCode",
            AVG("Rent") AS avg_rent
        FROM
            "public"."Zillow"
        WHERE
            "Time" BETWEEN '2015-01-01' AND '2023-09-30'
        GROUP BY
            "ZipCode"
    """

    query_trees = """
        SELECT
            "ZipCode",
            COUNT(*) AS num_trees
        FROM
            "public"."NYC_Tree"
        GROUP BY
            "ZipCode"
    """

    query_complaints = """
        SELECT
            "ZipCode",
            COUNT(*) AS num_complaints
        FROM
            "public"."NYC_311"
        WHERE
            "Time" BETWEEN '2015-01-01' AND '2023-09-30'
        GROUP BY
            "ZipCode"
    """

    # Use Pandas to read the query results
    df_rent = pd.read_sql_query(query_rent, engine)
    df_trees = pd.read_sql_query(query_trees, engine)
    df_complaints = pd.read_sql_query(query_complaints, engine)

    # Merge the dataframes on ZipCode
    df_combined = pd.merge(df_rent, df_trees, on="ZipCode", how="outer")
    df_combined = pd.merge(df_combined, df_complaints, on="ZipCode", how="outer")

    return df_combined

def plot_visual_3(dataframe):
    """This function helps to set up the visual plot for any data frames of V3"""
    fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(10, 8), sharex=True)

    sns.scatterplot(data=dataframe, y="num_trees", x="avg_rent", hue="num_trees", ax=axes, palette="coolwarm", marker='o', s=50, alpha=0.8, edgecolor='black')
    sns.scatterplot(data=dataframe, y="num_complaints", x="avg_rent", hue="num_complaints", ax=axes, palette="plasma", marker='s', s=50, alpha=0.8, edgecolor='black')
    axes.set_xlabel('Average Rent')

    axes.set_ylabel('Count of Tree or Complaints')

    axes.legend(title='Trees Count', loc='upper right')
    axes.legend(title='Complaints Count', loc='upper right')

    plt.tight_layout()
    plt.show()

# %% [markdown]
# _Call the function and get a full diagram of relationship between complaints/trees and rent_

# %%
some_dataframe = get_data_for_visual_3()
plot_visual_3(some_dataframe)

# %% [markdown]
# ### Visualization 4

# %% [markdown]
# _In this visualization we implement boxplots_

# %%
def plot_visual_4(engine, start_date, end_date):
    # Query for average rent
    query_rent = f"""
        SELECT
            "ZipCode",
            AVG("Rent") AS avg_rent
        FROM
            "public"."Zillow"
        WHERE
            "Time" = '{end_date}'
        GROUP BY
            "ZipCode"
    """
    df_rent = pd.read_sql_query(query_rent, engine)

    # Query for complaints
    query_complaints = f"""
        SELECT
            "ZipCode",
            COUNT(*) AS num_complaints
        FROM
            "public"."NYC_311"
        WHERE
            "Time" BETWEEN '{start_date}' AND '{end_date}'
        GROUP BY
            "ZipCode"
    """
    df_complaints = pd.read_sql_query(query_complaints, engine)
    df_combined = pd.merge(df_rent, df_complaints, on="ZipCode", how="inner")

    bins = list(range(0, int(df_combined['avg_rent'].max()) + 1001, 1000))
    df_combined['rent_bin'] = pd.cut(df_combined['avg_rent'], bins, labels=[f'${i}-{i+1000}' for i in range(0, int(df_combined['avg_rent'].max()), 1000)])

    # Plot boxplot with different color and style
    plt.figure(figsize=(12, 8))
    sns.boxplot(data=df_combined, x='rent_bin', y='num_complaints', color='skyblue', linewidth=2)
    plt.title(f'Boxplot of 311 Complaints vs. Average Rent ({end_date})')
    plt.xlabel(f'Average Rent in {end_date}')
    plt.ylabel('Number of 311 Complaints')
    plt.show()

# %%
plot_visual_4(engine, '2022-10-01', '2023-09-30')

# %% [markdown]
# ### Visualization 5

# %% [markdown]
# _create a map that shows recent 311 complaints_

# %%
def plot_visual_5(engine, center_latitude, center_longitude, radius, start_date, end_date):
    # SQL query for 311 complaints within a specified radius
    query_complaints = f"""
        SELECT
            "ZipCode",
            "Time",
            "Latitude",
            "Longitude"
        FROM
            "public"."NYC_311"
        WHERE
            ST_DWithin(
                ST_MakePoint({center_longitude}, {center_latitude})::geography,
                ST_MakePoint("Longitude", "Latitude")::geography,
                {radius} * 1609.34
            ) AND "Time" BETWEEN '{start_date}' AND '{end_date}';
    """

    # Read data into a GeoDataFrame
    df_complaints = pd.read_sql_query(query_complaints, engine)
    geometry_complaints = [shapely.geometry.Point(lon, lat) for lon, lat in zip(df_complaints['Longitude'], df_complaints['Latitude'])]
    gdf_complaints = gpd.GeoDataFrame(df_complaints, geometry=geometry_complaints, crs='EPSG:4326')

    # Plot the map
    fig, ax = plt.subplots(figsize=(12, 8))

    gdf_complaints.plot(ax=ax, color='purple', label='311 Complaints', markersize=10, alpha=0.7, edgecolor='black', linewidth=0.5)

    ax.set_title(f'311 Complaints')
    ax.set_xlabel('Longitude')
    ax.set_ylabel('Latitude')
    ax.legend()

    # Add grid
    ax.grid(True, linestyle='--', alpha=0.5)

    plt.show()

# %%
center_latitude = 40.80737875669467
center_longitude = -73.96253174434912
radius = 0.5
start_date = '2023-01-01'
end_date = '2023-09-30'
plot_visual_5(engine, center_latitude, center_longitude, radius, start_date, end_date)

# %% [markdown]
# ### Visualization 6

# %% [markdown]
# _Here we draw the map and it can indicate the spot for trees and the place where complaints take place_

# %%
def get_data_for_visual_6():
    query_trees = """
        SELECT
            "ID",
            "Latitude",
            "Longitude"
        FROM
            "NYC_Tree";
    """

    query_311 = """
        SELECT
            "Latitude",
            "Longitude"
        FROM
            "NYC_311"
        WHERE
            "ComplaintType" = 'New Tree Request'
            AND "Time" BETWEEN '2018-10-01' AND '2023-09-30';
    """

    # Use Pandas to read the query results
    df_trees = pd.read_sql_query(query_trees, engine)
    df_311 = pd.read_sql_query(query_311, engine)

    # Create GeoDataFrames with Point geometries
    geometry_trees = [shapely.geometry.Point(lon, lat) for lon, lat in zip(df_trees['Longitude'], df_trees['Latitude'])]
    gdf_trees = gpd.GeoDataFrame(df_trees, geometry=geometry_trees, crs='EPSG:4326')

    geometry_311 = [shapely.geometry.Point(lon, lat) for lon, lat in zip(df_311['Longitude'], df_311['Latitude'])]
    gdf_311 = gpd.GeoDataFrame(df_311, geometry=geometry_311, crs='EPSG:4326')

    return gdf_trees, gdf_311


def plot_visual_6(gdf_trees, gdf_311):
    """This function helps to set up the visual plot for any dataframes of V6"""
    fig, ax = plt.subplots(figsize=(12, 8))

    gdf_trees.plot(ax=ax, color='green', edgecolor='black', label='Trees', markersize=10)
    gdf_311.plot(ax=ax, color='red', edgecolor='black', label='New Tree Requests', marker='s', markersize=10)

    ax.set_title('Geospatial Plot of Trees and New Tree Requests')
    ax.set_xlabel('Longitude')
    ax.set_ylabel('Latitude')
    ax.legend()
    ax.grid(True, linestyle='--', alpha=0.5)

    plt.show()

# %%
gdf_trees, gdf_311 = get_data_for_visual_6()
plot_visual_6(gdf_trees, gdf_311)
